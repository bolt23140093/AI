# %%
cd '/content/drive/MyDrive/'
# Out:
# /content/drive/MyDrive

# %%
cd 'adv_python'
# Out:
# /content/drive/.shortcut-targets-by-id/1JT74aSTNQccpnVlF0voEpFw-T-FT0I7s/adv_python

# %%
ls -l
# Out:
# total 19
# -rw------- 1 root root 2642 Oct  8  2022 itertools.py
# -rw------- 1 root root 9649 Sep 11 06:12 test.ipynb
# -rw------- 1 root root 2921 Oct  6  2022 tree_DS.py
# -rw------- 1 root root 2940 Oct  2  2022 tutorial_set_operation.py

# %%
# !python itertools.py
# Out:
# defaultdict(<class 'int'>, {frozenset({'D'}): 0})
# -----frozenset as a index--------
# frozenset({'D'}) : 0
# frozenset({'B', 'A', 'C'}) : 2
# frozenset({'D', 'E'}) : 1
# -----frozenset with a set--------
# newitemsets: [[{'B'}, {'A'}, {'C'}], [{'B'}, {'A'}, {'E'}]]
# ----------
# {'B', 'A'}
# {'B', 'E'}
# {'B', 'A'}
# {'A', 'E'}
# {'B', 'C'}
# {'A', 'C'}
# {'C', 'E'}
# joinset: {frozenset({'A', 'E'}), frozenset({'C', 'E'}), frozenset({'B', 'A'}), frozenset({'B', 'C'}), frozenset({'A', 'C'}), frozenset({'B', 'E'})}
# -----chain--------
# [1, 3, 5, 7, 9, 2, 4, 6, 8, 10]

# %%
# %load itertools.py
