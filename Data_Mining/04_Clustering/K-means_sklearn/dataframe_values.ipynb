# %%
import pandas as pd
import numpy as np

# %%
data = np.array([[1, 4], [2, 5], [3, 6]])
df = pd.DataFrame(data, columns=['col1', 'col2']) # Specify column names
df
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6

# %%
df.values
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
type(df.values)
# Out:
# numpy.ndarray

# %%
df.values[:,0]
# Out:
# array([1, 2, 3])

# %%
df.iloc[:,0]
# Out:
# 0    1
# 1    2
# 2    3
# Name: col1, dtype: int64

# %%
type(df.iloc[:,0])
# Out:
# pandas.core.series.Series
