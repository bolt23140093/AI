# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # Predicting house prices: a regression example
#
#
# Do not mix up "regression" with the algorithm "logistic regression": confusingly, "logistic regression" is not a regression algorithm,
# it is a classification algorithm.

# %% [markdown]
# ## The Boston Housing Price dataset
#
#
# We will be attempting to predict the median price of homes in a given Boston suburb in the mid-1970s, given a few data points about the
# suburb at the time, such as the crime rate, the local property tax rate, etc.
#
# The dataset we will be using has another interesting difference from our two previous examples: it has very few data points, only 506 in
# total, split between 404 training samples and 102 test samples, and each "feature" in the input data (e.g. the crime rate is a feature) has
# a different scale. For instance some values are proportions, which take a values between 0 and 1, others take values between 1 and 12,
# others between 0 and 100...
#
# Let's take a look at the data:

# %%
from tensorflow.keras.datasets import boston_housing

(train_data, train_targets), (test_data, test_targets) =  boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step

# %%
train_data.shape
# Out:
# (404, 13)

# %%
test_data.shape
# Out:
# (102, 13)

# %% [markdown]
# As you can see, we have 404 training samples and 102 test samples. The data comprises 13 features. The 13 features in the input data are as
# follow:
#
# 1. Per capita crime rate.
# 2. Proportion of residential land zoned for lots over 25,000 square feet.
# 3. Proportion of non-retail business acres per town.
# 4. Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# 5. Nitric oxides concentration (parts per 10 million).
# 6. Average number of rooms per dwelling.
# 7. Proportion of owner-occupied units built prior to 1940.
# 8. Weighted distances to five Boston employment centres.
# 9. Index of accessibility to radial highways.
# 10. Full-value property-tax rate per $10,000.
# 11. Pupil-teacher ratio by town.
# 12. 1000 * (Bk - 0.63) ** 2 where Bk is the proportion of Black people by town.
# 13. % lower status of the population.
#
# The targets are the median values of owner-occupied homes, in thousands of dollars:

# %%
train_targets
# Out:
# array([15.2, 42.3, 50. , 21.1, 17.7, 18.5, 11.3, 15.6, 15.6, 14.4, 12.1,
#        17.9, 23.1, 19.9, 15.7,  8.8, 50. , 22.5, 24.1, 27.5, 10.9, 30.8,
#        32.9, 24. , 18.5, 13.3, 22.9, 34.7, 16.6, 17.5, 22.3, 16.1, 14.9,
#        23.1, 34.9, 25. , 13.9, 13.1, 20.4, 20. , 15.2, 24.7, 22.2, 16.7,
#        12.7, 15.6, 18.4, 21. , 30.1, 15.1, 18.7,  9.6, 31.5, 24.8, 19.1,
#        22. , 14.5, 11. , 32. , 29.4, 20.3, 24.4, 14.6, 19.5, 14.1, 14.3,
#        15.6, 10.5,  6.3, 19.3, 19.3, 13.4, 36.4, 17.8, 13.5, 16.5,  8.3,
#        14.3, 16. , 13.4, 28.6, 43.5, 20.2, 22. , 23. , 20.7, 12.5, 48.5,
#        14.6, 13.4, 23.7, 50. , 21.7, 39.8, 38.7, 22.2, 34.9, 22.5, 31.1,
#        28.7, 46. , 41.7, 21. , 26.6, 15. , 24.4, 13.3, 21.2, 11.7, 21.7,
#        19.4, 50. , 22.8, 19.7, 24.7, 36.2, 14.2, 18.9, 18.3, 20.6, 24.6,
#        18.2,  8.7, 44. , 10.4, 13.2, 21.2, 37. , 30.7, 22.9, 20. , 19.3,
#        31.7, 32. , 23.1, 18.8, 10.9, 50. , 19.6,  5. , 14.4, 19.8, 13.8,
#        19.6, 23.9, 24.5, 25. , 19.9, 17.2, 24.6, 13.5, 26.6, 21.4, 11.9,
#        22.6, 19.6,  8.5, 23.7, 23.1, 22.4, 20.5, 23.6, 18.4, 35.2, 23.1,
#        27.9, 20.6, 23.7, 28. , 13.6, 27.1, 23.6, 20.6, 18.2, 21.7, 17.1,
#         8.4, 25.3, 13.8, 22.2, 18.4, 20.7, 31.6, 30.5, 20.3,  8.8, 19.2,
#        19.4, 23.1, 23. , 14.8, 48.8, 22.6, 33.4, 21.1, 13.6, 32.2, 13.1,
#        23.4, 18.9, 23.9, 11.8, 23.3, 22.8, 19.6, 16.7, 13.4, 22.2, 20.4,
#        21.8, 26.4, 14.9, 24.1, 23.8, 12.3, 29.1, 21. , 19.5, 23.3, 23.8,
#        17.8, 11.5, 21.7, 19.9, 25. , 33.4, 28.5, 21.4, 24.3, 27.5, 33.1,
#        16.2, 23.3, 48.3, 22.9, 22.8, 13.1, 12.7, 22.6, 15. , 15.3, 10.5,
#        24. , 18.5, 21.7, 19.5, 33.2, 23.2,  5. , 19.1, 12.7, 22.3, 10.2,
#        13.9, 16.3, 17. , 20.1, 29.9, 17.2, 37.3, 45.4, 17.8, 23.2, 29. ,
#        22. , 18. , 17.4, 34.6, 20.1, 25. , 15.6, 24.8, 28.2, 21.2, 21.4,
#        23.8, 31. , 26.2, 17.4, 37.9, 17.5, 20. ,  8.3, 23.9,  8.4, 13.8,
#         7.2, 11.7, 17.1, 21.6, 50. , 16.1, 20.4, 20.6, 21.4, 20.6, 36.5,
#         8.5, 24.8, 10.8, 21.9, 17.3, 18.9, 36.2, 14.9, 18.2, 33.3, 21.8,
#        19.7, 31.6, 24.8, 19.4, 22.8,  7.5, 44.8, 16.8, 18.7, 50. , 50. ,
#        19.5, 20.1, 50. , 17.2, 20.8, 19.3, 41.3, 20.4, 20.5, 13.8, 16.5,
#        23.9, 20.6, 31.5, 23.3, 16.8, 14. , 33.8, 36.1, 12.8, 18.3, 18.7,
#        19.1, 29. , 30.1, 50. , 50. , 22. , 11.9, 37.6, 50. , 22.7, 20.8,
#        23.5, 27.9, 50. , 19.3, 23.9, 22.6, 15.2, 21.7, 19.2, 43.8, 20.3,
#        33.2, 19.9, 22.5, 32.7, 22. , 17.1, 19. , 15. , 16.1, 25.1, 23.7,
#        28.7, 37.2, 22.6, 16.4, 25. , 29.8, 22.1, 17.4, 18.1, 30.3, 17.5,
#        24.7, 12.6, 26.5, 28.7, 13.3, 10.4, 24.4, 23. , 20. , 17.8,  7. ,
#        11.8, 24.4, 13.8, 19.4, 25.2, 19.4, 19.4, 29.1])

# %% [markdown]
# The prices are typically between \$10,000 and \$50,000. If that sounds cheap, remember this was the mid-1970s, and these prices are not
# inflation-adjusted.

# %% [markdown]
# ## Preparing the data
#
#
# It would be problematic to feed into a neural network values that all take wildly different ranges. The network might be able to
# automatically adapt to such heterogeneous data, but it would definitely make learning more difficult. A widespread best practice to deal
# with such data is to do feature-wise normalization: for each feature in the input data (a column in the input data matrix), we
# will subtract the mean of the feature and divide by the standard deviation, so that the feature will be centered around 0 and will have a
# unit standard deviation. This is easily done in Numpy:

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std

test_data -= mean
test_data /= std

# %%
import numpy as np

data_num = train_data.shape[0]
# 取得一筆與data數量相同的亂數索引，主要目的是用於打散資料
indexes = np.random.permutation(data_num)
# 並將亂數索引值分為Train、validation分為，這裡的劃分比例為8:2
train_indexes = indexes[:int(data_num *0.8)]
val_indexes = indexes[int(data_num *0.8):]
# 透過索引值從data取出訓練資料、驗證資料和測試資料
val_data = train_data[val_indexes]
train_data = train_data[train_indexes]
val_targets = train_targets[val_indexes]
train_targets = train_targets[train_indexes]

# %% [markdown]
# Note that the quantities that we use for normalizing the test data have been computed using the training data. We should never use in our
# workflow any quantity computed on the test data, even for something as simple as data normalization.

# %% [markdown]
# ## Building our network
#
#
# Because so few samples are available, we will be using a very small network with two
# hidden layers, each with 64 units. In general, the less training data you have, the worse overfitting will be, and using
# a small network is one way to mitigate overfitting.

# %%
from tensorflow.keras import layers
# 建立一個Sequential型態的model
model = keras.Sequential(name='model-1')
# 第1層全連接層設為64個unit，將輸入形狀設定為(13, )，而實際上我們輸入的數據形狀為(batch_size, 13)
model.add(layers.Dense(64, activation='relu', input_shape=(13,)))
# 第2層全連接層設為64個unit
model.add(layers.Dense(64, activation='relu'))
# 最後一層全連接層設為1個unit
model.add(layers.Dense(1))
# 顯示網路模型架構
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "model-1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,121 (20.00 KB)
#  Trainable params: 5,121 (20.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(keras.optimizers.Adam(0.001),
              loss=keras.losses.MeanSquaredError(),
              metrics=[keras.metrics.MeanAbsoluteError()])

# %%
import os

model_dir = 'lab1-logs/models/'
os.makedirs(model_dir)
# TensorBoard回調函數會幫忙紀錄訓練資訊，並存成TensorBoard的紀錄檔
log_dir = os.path.join('lab1-logs', 'model-1')
model_cbk = keras.callbacks.TensorBoard(log_dir=log_dir)
# ModelCheckpoint回調函數幫忙儲存網路模型，可以設定只儲存最好的模型，「monitor」表示被監測的數據，「mode」min則代表監測數據越小越好。
model_mckp = keras.callbacks.ModelCheckpoint(model_dir + '/Best-model-1.keras',
                                        monitor='val_mean_absolute_error',
                                        save_best_only=True,
                                        mode='min')

# %%
history = model.fit(train_data, train_targets,  # 傳入訓練數據
               batch_size=16,  # 批次大小設為16
               epochs=100,  # 整個dataset訓練100遍
               validation_data=(val_data, val_targets),  # 驗證數據
               callbacks=[model_cbk, model_mckp])  # Tensorboard回調函數紀錄訓練過程，ModelCheckpoint回調函數儲存最好的模型
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 585.1858 - mean_absolute_error: 22.1680 - val_loss: 451.4896 - val_mean_absolute_error: 19.8399
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 537.9955 - mean_absolute_error: 21.0384 - val_loss: 366.3507 - val_mean_absolute_error: 17.4869
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 429.5475 - mean_absolute_error: 18.0475 - val_loss: 236.3054 - val_mean_absolute_error: 13.5934
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 275.3263 - mean_absolute_error: 14.0158 - val_loss: 97.8712 - val_mean_absolute_error: 8.4313
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 121.3948 - mean_absolute_error: 8.4175 - val_loss: 35.3323 - val_mean_absolute_error: 4.9890
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 54.6969 - mean_absolute_error: 5.6562 - val_loss: 23.5838 - val_mean_absolute_error: 4.0503
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 46.0503 - mean_absolute_error: 4.6242 - val_loss: 16.3735 - val_mean_absolute_error: 3.3463
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.4700 - mean_absolute_error: 3.8488 - val_loss: 14.8440 - val_mean_absolute_error: 3.1732
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.8356 - mean_absolute_error: 3.5080 - val_loss: 13.5031 - val_mean_absolute_error: 3.0348
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.9097 - mean_absolute_error: 3.5884 - val_loss: 13.5157 - val_mean_absolute_error: 3.0227
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.1115 - mean_absolute_error: 3.2818 - val_loss: 11.9830 - val_mean_absolute_error: 2.8552
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.7323 - mean_absolute_error: 3.1632 - val_loss: 11.2146 - val_mean_absolute_error: 2.7499
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.6060 - mean_absolute_error: 3.1431 - val_loss: 9.8329 - val_mean_absolute_error: 2.5793
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.1751 - mean_absolute_error: 2.7992 - val_loss: 11.6141 - val_mean_absolute_error: 2.7119
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.1597 - mean_absolute_error: 2.8358 - val_loss: 8.9873 - val_mean_absolute_error: 2.4139
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.3910 - mean_absolute_error: 3.0096 - val_loss: 9.4250 - val_mean_absolute_error: 2.4371
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.8946 - mean_absolute_error: 2.7776 - val_loss: 8.5091 - val_mean_absolute_error: 2.3176
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.1171 - mean_absolute_error: 2.9275 - val_loss: 9.0026 - val_mean_absolute_error: 2.3784
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.8535 - mean_absolute_error: 2.7410 - val_loss: 8.4401 - val_mean_absolute_error: 2.3005
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.5753 - mean_absolute_error: 2.8049 - val_loss: 8.4275 - val_mean_absolute_error: 2.2804
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.6650 - mean_absolute_error: 2.7527 - val_loss: 8.4808 - val_mean_absolute_error: 2.2660
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.9612 - mean_absolute_error: 2.7106 - val_loss: 8.3436 - val_mean_absolute_error: 2.2549
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 12.0620 - mean_absolute_error: 2.5769 - val_loss: 8.0350 - val_mean_absolute_error: 2.2002
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 10.9746 - mean_absolute_error: 2.3570 - val_loss: 8.0829 - val_mean_absolute_error: 2.1996
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.6404 - mean_absolute_error: 2.5321 - val_loss: 8.0808 - val_mean_absolute_error: 2.2067
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 14.3276 - mean_absolute_error: 2.7348 - val_loss: 7.8245 - val_mean_absolute_error: 2.1598
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.8216 - mean_absolute_error: 2.4621 - val_loss: 8.0216 - val_mean_absolute_error: 2.1882
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.3099 - mean_absolute_error: 2.6777 - val_loss: 7.9070 - val_mean_absolute_error: 2.1726
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.2709 - mean_absolute_error: 2.5867 - val_loss: 8.5341 - val_mean_absolute_error: 2.2627
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.9920 - mean_absolute_error: 2.4822 - val_loss: 7.4885 - val_mean_absolute_error: 2.1008
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.7505 - mean_absolute_error: 2.4604 - val_loss: 8.2155 - val_mean_absolute_error: 2.2210
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.6235 - mean_absolute_error: 2.4072 - val_loss: 7.6122 - val_mean_absolute_error: 2.1139
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5174 - mean_absolute_error: 2.2830 - val_loss: 8.0928 - val_mean_absolute_error: 2.1919
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.2966 - mean_absolute_error: 2.3649 - val_loss: 7.5598 - val_mean_absolute_error: 2.0914
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7642 - mean_absolute_error: 2.3003 - val_loss: 7.9550 - val_mean_absolute_error: 2.1826
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.3198 - mean_absolute_error: 2.3354 - val_loss: 7.5250 - val_mean_absolute_error: 2.0956
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.3046 - mean_absolute_error: 2.3141 - val_loss: 8.1193 - val_mean_absolute_error: 2.1819
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.1769 - mean_absolute_error: 2.1963 - val_loss: 8.0751 - val_mean_absolute_error: 2.1583
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.0589 - mean_absolute_error: 2.2756 - val_loss: 8.2737 - val_mean_absolute_error: 2.1975
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.9715 - mean_absolute_error: 2.2463 - val_loss: 7.8379 - val_mean_absolute_error: 2.1127
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5027 - mean_absolute_error: 2.1548 - val_loss: 7.7113 - val_mean_absolute_error: 2.0971
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.1364 - mean_absolute_error: 2.1340 - val_loss: 8.3611 - val_mean_absolute_error: 2.1948
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.2619 - mean_absolute_error: 2.1479 - val_loss: 8.2133 - val_mean_absolute_error: 2.1749
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9420 - mean_absolute_error: 2.1969 - val_loss: 7.8896 - val_mean_absolute_error: 2.1110
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4777 - mean_absolute_error: 2.0818 - val_loss: 8.1527 - val_mean_absolute_error: 2.1483
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5555 - mean_absolute_error: 2.0440 - val_loss: 8.0650 - val_mean_absolute_error: 2.1268
# Epoch 47/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.3282 - mean_absolute_error: 2.1365 - val_loss: 8.7620 - val_mean_absolute_error: 2.2362
# Epoch 48/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9385 - mean_absolute_error: 2.1009 - val_loss: 8.4640 - val_mean_absolute_error: 2.1823
# Epoch 49/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.4794 - mean_absolute_error: 2.2937 - val_loss: 8.1177 - val_mean_absolute_error: 2.1246
# Epoch 50/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9602 - mean_absolute_error: 2.1602 - val_loss: 8.2208 - val_mean_absolute_error: 2.1326
# Epoch 51/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2355 - mean_absolute_error: 2.0055 - val_loss: 8.3058 - val_mean_absolute_error: 2.1541
# Epoch 52/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3320 - mean_absolute_error: 2.0995 - val_loss: 8.5608 - val_mean_absolute_error: 2.1884
# Epoch 53/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8004 - mean_absolute_error: 2.1749 - val_loss: 8.4875 - val_mean_absolute_error: 2.1819
# Epoch 54/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.1694 - mean_absolute_error: 2.1929 - val_loss: 8.6754 - val_mean_absolute_error: 2.2071
# Epoch 55/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2673 - mean_absolute_error: 1.9528 - val_loss: 8.5185 - val_mean_absolute_error: 2.1770
# Epoch 56/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8211 - mean_absolute_error: 2.0414 - val_loss: 8.1217 - val_mean_absolute_error: 2.1160
# Epoch 57/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7249 - mean_absolute_error: 1.9934 - val_loss: 8.3887 - val_mean_absolute_error: 2.1650
# Epoch 58/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2448 - mean_absolute_error: 2.1332 - val_loss: 8.7144 - val_mean_absolute_error: 2.1870
# Epoch 59/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1599 - mean_absolute_error: 1.9506 - val_loss: 8.5106 - val_mean_absolute_error: 2.1801
# Epoch 60/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9001 - mean_absolute_error: 2.2042 - val_loss: 8.1580 - val_mean_absolute_error: 2.1002
# Epoch 61/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.7817 - mean_absolute_error: 2.2140 - val_loss: 8.1895 - val_mean_absolute_error: 2.1143
# Epoch 62/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9456 - mean_absolute_error: 1.9913 - val_loss: 8.6386 - val_mean_absolute_error: 2.1853
# Epoch 63/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6552 - mean_absolute_error: 1.9526 - val_loss: 8.7116 - val_mean_absolute_error: 2.1864
# Epoch 64/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5116 - mean_absolute_error: 2.0520 - val_loss: 8.4269 - val_mean_absolute_error: 2.1425
# Epoch 65/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3544 - mean_absolute_error: 1.9480 - val_loss: 8.9888 - val_mean_absolute_error: 2.2256
# Epoch 66/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4931 - mean_absolute_error: 1.9765 - val_loss: 8.2612 - val_mean_absolute_error: 2.1056
# Epoch 67/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3110 - mean_absolute_error: 2.0172 - val_loss: 8.3435 - val_mean_absolute_error: 2.1363
# Epoch 68/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7343 - mean_absolute_error: 2.1011 - val_loss: 8.5450 - val_mean_absolute_error: 2.1247
# Epoch 69/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2945 - mean_absolute_error: 1.9671 - val_loss: 8.9608 - val_mean_absolute_error: 2.2263
# Epoch 70/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1251 - mean_absolute_error: 1.9685 - val_loss: 8.7457 - val_mean_absolute_error: 2.1738
# Epoch 71/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3656 - mean_absolute_error: 2.0023 - val_loss: 8.8514 - val_mean_absolute_error: 2.1923
# Epoch 72/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8746 - mean_absolute_error: 1.9376 - val_loss: 8.5790 - val_mean_absolute_error: 2.1619
# Epoch 73/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8847 - mean_absolute_error: 1.7947 - val_loss: 9.0269 - val_mean_absolute_error: 2.1965
# Epoch 74/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0452 - mean_absolute_error: 2.0082 - val_loss: 8.1324 - val_mean_absolute_error: 2.0821
# Epoch 75/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2024 - mean_absolute_error: 1.7808 - val_loss: 9.1154 - val_mean_absolute_error: 2.2141
# Epoch 76/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.5059 - mean_absolute_error: 2.0225 - val_loss: 8.9065 - val_mean_absolute_error: 2.1828
# Epoch 77/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8194 - mean_absolute_error: 1.9108 - val_loss: 8.8084 - val_mean_absolute_error: 2.1776
# Epoch 78/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1758 - mean_absolute_error: 1.8763 - val_loss: 8.8918 - val_mean_absolute_error: 2.1842
# Epoch 79/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3693 - mean_absolute_error: 2.1754 - val_loss: 7.9130 - val_mean_absolute_error: 2.0159
# Epoch 80/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3805 - mean_absolute_error: 1.8777 - val_loss: 9.3295 - val_mean_absolute_error: 2.2240
# Epoch 81/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3497 - mean_absolute_error: 1.9114 - val_loss: 8.8054 - val_mean_absolute_error: 2.1575
# Epoch 82/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1548 - mean_absolute_error: 1.9012 - val_loss: 8.8827 - val_mean_absolute_error: 2.1744
# Epoch 83/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8449 - mean_absolute_error: 1.8591 - val_loss: 8.6747 - val_mean_absolute_error: 2.1316
# Epoch 84/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2617 - mean_absolute_error: 1.7597 - val_loss: 8.6616 - val_mean_absolute_error: 2.1282
# Epoch 85/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4274 - mean_absolute_error: 1.8549 - val_loss: 8.7481 - val_mean_absolute_error: 2.1478
# Epoch 86/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0161 - mean_absolute_error: 1.8704 - val_loss: 9.0778 - val_mean_absolute_error: 2.1755
# Epoch 87/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3824 - mean_absolute_error: 1.9020 - val_loss: 8.8605 - val_mean_absolute_error: 2.0926
# Epoch 88/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0431 - mean_absolute_error: 1.9162 - val_loss: 9.8025 - val_mean_absolute_error: 2.2433
# Epoch 89/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1699 - mean_absolute_error: 1.8031 - val_loss: 9.0590 - val_mean_absolute_error: 2.1446
# Epoch 90/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2878 - mean_absolute_error: 1.8823 - val_loss: 9.1066 - val_mean_absolute_error: 2.1561
# Epoch 91/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5189 - mean_absolute_error: 1.7681 - val_loss: 9.6723 - val_mean_absolute_error: 2.2427
# Epoch 92/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5109 - mean_absolute_error: 1.7949 - val_loss: 9.0310 - val_mean_absolute_error: 2.1343
# Epoch 93/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9908 - mean_absolute_error: 1.8539 - val_loss: 9.3090 - val_mean_absolute_error: 2.1703
# Epoch 94/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2910 - mean_absolute_error: 1.9221 - val_loss: 8.8635 - val_mean_absolute_error: 2.1231
# Epoch 95/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9541 - mean_absolute_error: 1.7110 - val_loss: 9.7279 - val_mean_absolute_error: 2.2394
# Epoch 96/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0811 - mean_absolute_error: 1.8812 - val_loss: 8.7694 - val_mean_absolute_error: 2.1109
# Epoch 97/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3298 - mean_absolute_error: 1.7033 - val_loss: 9.5376 - val_mean_absolute_error: 2.2007
# Epoch 98/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2196 - mean_absolute_error: 1.9332 - val_loss: 8.5528 - val_mean_absolute_error: 2.0822
# Epoch 99/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4094 - mean_absolute_error: 1.7815 - val_loss: 10.3023 - val_mean_absolute_error: 2.3075
# Epoch 100/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5774 - mean_absolute_error: 1.9442 - val_loss: 8.8302 - val_mean_absolute_error: 2.1230

# %%
history.history.keys()  # 查看history儲存的資訊有哪些
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.title('Mean square error')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')

# %%
plt.plot(history.history['mean_absolute_error'], label='train')
plt.plot(history.history['val_mean_absolute_error'], label='validation')
plt.title('Mean absolute error')
plt.ylabel('metrics')
plt.xlabel('epochs')
plt.legend(loc='upper right')

# %%
model = keras.models.load_model('lab1-logs/models/Best-model-1.keras')

# 預測測試數據
y_pred = model.predict(test_data)
print(y_pred.shape)
print(test_targets.shape)

# 不需要將預測結果轉換回來(因為訓練時的訓練目標並沒有經過標準化)
# y_pred = np.reshape(y_pred * std['price'] + mean['price'], y_test.shape)

y_pred = np.reshape(y_pred, test_targets.shape)
print(y_pred.shape, test_targets.shape)
# 計算平均的誤差百分比
percentage_error = np.mean(np.abs(test_targets - y_pred) / test_targets) * 100
# 顯示誤差百分比
print("Model_1 Percentage Error: {:.2f}%".format(percentage_error))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step
# (102, 1)
# (102,)
# (102,) (102,)
# Model_1 Percentage Error: 14.43%
