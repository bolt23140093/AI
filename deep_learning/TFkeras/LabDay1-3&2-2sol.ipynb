# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # Predicting house prices: a regression example
#
#
# Do not mix up "regression" with the algorithm "logistic regression": confusingly, "logistic regression" is not a regression algorithm,
# it is a classification algorithm.

# %% [markdown]
# ## The Boston Housing Price dataset
#
#
# We will be attempting to predict the median price of homes in a given Boston suburb in the mid-1970s, given a few data points about the
# suburb at the time, such as the crime rate, the local property tax rate, etc.
#
# The dataset we will be using has another interesting difference from our two previous examples: it has very few data points, only 506 in
# total, split between 404 training samples and 102 test samples, and each "feature" in the input data (e.g. the crime rate is a feature) has
# a different scale. For instance some values are proportions, which take a values between 0 and 1, others take values between 1 and 12,
# others between 0 and 100...
#
# Let's take a look at the data:

# %%
from tensorflow.keras.datasets import boston_housing

(train_data, train_targets), (test_data, test_targets) =  boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 0us/step

# %%
train_data.shape
# Out:
# (404, 13)

# %%
test_data.shape
# Out:
# (102, 13)

# %% [markdown]
# As you can see, we have 404 training samples and 102 test samples. The data comprises 13 features. The 13 features in the input data are as
# follow:
#
# 1. Per capita crime rate.
# 2. Proportion of residential land zoned for lots over 25,000 square feet.
# 3. Proportion of non-retail business acres per town.
# 4. Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# 5. Nitric oxides concentration (parts per 10 million).
# 6. Average number of rooms per dwelling.
# 7. Proportion of owner-occupied units built prior to 1940.
# 8. Weighted distances to five Boston employment centres.
# 9. Index of accessibility to radial highways.
# 10. Full-value property-tax rate per $10,000.
# 11. Pupil-teacher ratio by town.
# 12. 1000 * (Bk - 0.63) ** 2 where Bk is the proportion of Black people by town.
# 13. % lower status of the population.
#
# The targets are the median values of owner-occupied homes, in thousands of dollars:

# %%
train_targets
# Out:
# array([15.2, 42.3, 50. , 21.1, 17.7, 18.5, 11.3, 15.6, 15.6, 14.4, 12.1,
#        17.9, 23.1, 19.9, 15.7,  8.8, 50. , 22.5, 24.1, 27.5, 10.9, 30.8,
#        32.9, 24. , 18.5, 13.3, 22.9, 34.7, 16.6, 17.5, 22.3, 16.1, 14.9,
#        23.1, 34.9, 25. , 13.9, 13.1, 20.4, 20. , 15.2, 24.7, 22.2, 16.7,
#        12.7, 15.6, 18.4, 21. , 30.1, 15.1, 18.7,  9.6, 31.5, 24.8, 19.1,
#        22. , 14.5, 11. , 32. , 29.4, 20.3, 24.4, 14.6, 19.5, 14.1, 14.3,
#        15.6, 10.5,  6.3, 19.3, 19.3, 13.4, 36.4, 17.8, 13.5, 16.5,  8.3,
#        14.3, 16. , 13.4, 28.6, 43.5, 20.2, 22. , 23. , 20.7, 12.5, 48.5,
#        14.6, 13.4, 23.7, 50. , 21.7, 39.8, 38.7, 22.2, 34.9, 22.5, 31.1,
#        28.7, 46. , 41.7, 21. , 26.6, 15. , 24.4, 13.3, 21.2, 11.7, 21.7,
#        19.4, 50. , 22.8, 19.7, 24.7, 36.2, 14.2, 18.9, 18.3, 20.6, 24.6,
#        18.2,  8.7, 44. , 10.4, 13.2, 21.2, 37. , 30.7, 22.9, 20. , 19.3,
#        31.7, 32. , 23.1, 18.8, 10.9, 50. , 19.6,  5. , 14.4, 19.8, 13.8,
#        19.6, 23.9, 24.5, 25. , 19.9, 17.2, 24.6, 13.5, 26.6, 21.4, 11.9,
#        22.6, 19.6,  8.5, 23.7, 23.1, 22.4, 20.5, 23.6, 18.4, 35.2, 23.1,
#        27.9, 20.6, 23.7, 28. , 13.6, 27.1, 23.6, 20.6, 18.2, 21.7, 17.1,
#         8.4, 25.3, 13.8, 22.2, 18.4, 20.7, 31.6, 30.5, 20.3,  8.8, 19.2,
#        19.4, 23.1, 23. , 14.8, 48.8, 22.6, 33.4, 21.1, 13.6, 32.2, 13.1,
#        23.4, 18.9, 23.9, 11.8, 23.3, 22.8, 19.6, 16.7, 13.4, 22.2, 20.4,
#        21.8, 26.4, 14.9, 24.1, 23.8, 12.3, 29.1, 21. , 19.5, 23.3, 23.8,
#        17.8, 11.5, 21.7, 19.9, 25. , 33.4, 28.5, 21.4, 24.3, 27.5, 33.1,
#        16.2, 23.3, 48.3, 22.9, 22.8, 13.1, 12.7, 22.6, 15. , 15.3, 10.5,
#        24. , 18.5, 21.7, 19.5, 33.2, 23.2,  5. , 19.1, 12.7, 22.3, 10.2,
#        13.9, 16.3, 17. , 20.1, 29.9, 17.2, 37.3, 45.4, 17.8, 23.2, 29. ,
#        22. , 18. , 17.4, 34.6, 20.1, 25. , 15.6, 24.8, 28.2, 21.2, 21.4,
#        23.8, 31. , 26.2, 17.4, 37.9, 17.5, 20. ,  8.3, 23.9,  8.4, 13.8,
#         7.2, 11.7, 17.1, 21.6, 50. , 16.1, 20.4, 20.6, 21.4, 20.6, 36.5,
#         8.5, 24.8, 10.8, 21.9, 17.3, 18.9, 36.2, 14.9, 18.2, 33.3, 21.8,
#        19.7, 31.6, 24.8, 19.4, 22.8,  7.5, 44.8, 16.8, 18.7, 50. , 50. ,
#        19.5, 20.1, 50. , 17.2, 20.8, 19.3, 41.3, 20.4, 20.5, 13.8, 16.5,
#        23.9, 20.6, 31.5, 23.3, 16.8, 14. , 33.8, 36.1, 12.8, 18.3, 18.7,
#        19.1, 29. , 30.1, 50. , 50. , 22. , 11.9, 37.6, 50. , 22.7, 20.8,
#        23.5, 27.9, 50. , 19.3, 23.9, 22.6, 15.2, 21.7, 19.2, 43.8, 20.3,
#        33.2, 19.9, 22.5, 32.7, 22. , 17.1, 19. , 15. , 16.1, 25.1, 23.7,
#        28.7, 37.2, 22.6, 16.4, 25. , 29.8, 22.1, 17.4, 18.1, 30.3, 17.5,
#        24.7, 12.6, 26.5, 28.7, 13.3, 10.4, 24.4, 23. , 20. , 17.8,  7. ,
#        11.8, 24.4, 13.8, 19.4, 25.2, 19.4, 19.4, 29.1])

# %% [markdown]
# The prices are typically between \$10,000 and \$50,000. If that sounds cheap, remember this was the mid-1970s, and these prices are not
# inflation-adjusted.

# %% [markdown]
# ## Preparing the data
#
#
# It would be problematic to feed into a neural network values that all take wildly different ranges. The network might be able to
# automatically adapt to such heterogeneous data, but it would definitely make learning more difficult. A widespread best practice to deal
# with such data is to do feature-wise normalization: for each feature in the input data (a column in the input data matrix), we
# will subtract the mean of the feature and divide by the standard deviation, so that the feature will be centered around 0 and will have a
# unit standard deviation. This is easily done in Numpy:

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std

test_data -= mean
test_data /= std

# %%
import numpy as np

data_num = train_data.shape[0]
# 取得一筆與data數量相同的亂數索引，主要目的是用於打散資料
indexes = np.random.permutation(data_num)
# 並將亂數索引值分為Train、validation分為，這裡的劃分比例為8:2
train_indexes = indexes[:int(data_num *0.8)]
val_indexes = indexes[int(data_num *0.8):]
# 透過索引值從data取出訓練資料、驗證資料和測試資料
val_data = train_data[val_indexes]
train_data = train_data[train_indexes]
val_targets = train_targets[val_indexes]
train_targets = train_targets[train_indexes]

# %% [markdown]
# Note that the quantities that we use for normalizing the test data have been computed using the training data. We should never use in our
# workflow any quantity computed on the test data, even for something as simple as data normalization.

# %% [markdown]
# ## Building our network
#
#
# Because so few samples are available, we will be using a very small network with two
# hidden layers, each with 64 units. In general, the less training data you have, the worse overfitting will be, and using
# a small network is one way to mitigate overfitting.

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
# 建立一個Sequential型態的model
model = keras.Sequential(name='model-1')
# 第1層全連接層設為64個unit，將輸入形狀設定為(13, )，而實際上我們輸入的數據形狀為(batch_size, 13)
model.add(layers.Dense(64, activation='relu', input_shape=(13,)))
# 第2層全連接層設為64個unit
model.add(layers.Dense(64, activation='relu'))
# 最後一層全連接層設為1個unit
model.add(layers.Dense(1))
# 顯示網路模型架構
model.summary()
# Out:
# Model: "model-1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                896
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(keras.optimizers.Adam(0.001),
              loss=keras.losses.MeanSquaredError(),
              metrics=[keras.metrics.MeanAbsoluteError()])

# %%
import os

model_dir = 'lab1-logs/models/'
os.makedirs(model_dir)
# TensorBoard回調函數會幫忙紀錄訓練資訊，並存成TensorBoard的紀錄檔
log_dir = os.path.join('lab1-logs', 'model-1')
model_cbk = keras.callbacks.TensorBoard(log_dir=log_dir)
# ModelCheckpoint回調函數幫忙儲存網路模型，可以設定只儲存最好的模型，「monitor」表示被監測的數據，「mode」min則代表監測數據越小越好。
model_mckp = keras.callbacks.ModelCheckpoint(model_dir + '/Best-model-1.keras',
                                        monitor='val_mean_absolute_error',
                                        save_best_only=True,
                                        mode='min')

# %%
history = model.fit(train_data, train_targets,  # 傳入訓練數據
               batch_size=16,  # 批次大小設為16
               epochs=100,  # 整個dataset訓練100遍
               validation_data=(val_data, val_targets),  # 驗證數據
               callbacks=[model_cbk, model_mckp])  # Tensorboard回調函數紀錄訓練過程，ModelCheckpoint回調函數儲存最好的模型
# Out:
# Epoch 1/100
# 21/21 [==============================] - 6s 66ms/step - loss: 549.8732 - mean_absolute_error: 21.5047 - val_loss: 523.8311 - val_mean_absolute_error: 21.1326
# Epoch 2/100
# 21/21 [==============================] - 0s 22ms/step - loss: 455.3241 - mean_absolute_error: 19.1217 - val_loss: 405.2688 - val_mean_absolute_error: 18.1248
# Epoch 3/100
# 21/21 [==============================] - 0s 24ms/step - loss: 315.0590 - mean_absolute_error: 15.2431 - val_loss: 233.0393 - val_mean_absolute_error: 13.0863
# Epoch 4/100
# 21/21 [==============================] - 1s 33ms/step - loss: 153.2482 - mean_absolute_error: 9.8981 - val_loss: 95.1267 - val_mean_absolute_error: 7.2206
# Epoch 5/100
# 21/21 [==============================] - 1s 27ms/step - loss: 70.7106 - mean_absolute_error: 6.2043 - val_loss: 61.4115 - val_mean_absolute_error: 5.7684
# Epoch 6/100
# 21/21 [==============================] - 1s 26ms/step - loss: 47.1117 - mean_absolute_error: 5.0195 - val_loss: 43.0827 - val_mean_absolute_error: 4.4828
# Epoch 7/100
# 21/21 [==============================] - 1s 47ms/step - loss: 32.8938 - mean_absolute_error: 4.1517 - val_loss: 34.1089 - val_mean_absolute_error: 3.8173
# Epoch 8/100
# 21/21 [==============================] - 1s 42ms/step - loss: 26.6236 - mean_absolute_error: 3.6953 - val_loss: 29.6473 - val_mean_absolute_error: 3.4921
# Epoch 9/100
# 21/21 [==============================] - 1s 26ms/step - loss: 23.4639 - mean_absolute_error: 3.4043 - val_loss: 27.6031 - val_mean_absolute_error: 3.2308
# Epoch 10/100
# 21/21 [==============================] - 0s 13ms/step - loss: 21.3987 - mean_absolute_error: 3.3132 - val_loss: 25.2955 - val_mean_absolute_error: 3.1269
# Epoch 11/100
# 21/21 [==============================] - 0s 14ms/step - loss: 19.5045 - mean_absolute_error: 3.1655 - val_loss: 24.4522 - val_mean_absolute_error: 3.0076
# Epoch 12/100
# 21/21 [==============================] - 0s 12ms/step - loss: 18.0767 - mean_absolute_error: 3.0286 - val_loss: 23.1912 - val_mean_absolute_error: 2.9667
# Epoch 13/100
# 21/21 [==============================] - 0s 11ms/step - loss: 16.9116 - mean_absolute_error: 2.9316 - val_loss: 21.7961 - val_mean_absolute_error: 2.8812
# Epoch 14/100
# 21/21 [==============================] - 0s 19ms/step - loss: 15.8984 - mean_absolute_error: 2.8501 - val_loss: 21.3740 - val_mean_absolute_error: 2.8356
# Epoch 15/100
# 21/21 [==============================] - 0s 17ms/step - loss: 15.0741 - mean_absolute_error: 2.7609 - val_loss: 20.3436 - val_mean_absolute_error: 2.7805
# Epoch 16/100
# 21/21 [==============================] - 0s 19ms/step - loss: 14.3153 - mean_absolute_error: 2.7063 - val_loss: 20.2060 - val_mean_absolute_error: 2.7515
# Epoch 17/100
# 21/21 [==============================] - 0s 17ms/step - loss: 13.7078 - mean_absolute_error: 2.6423 - val_loss: 19.4865 - val_mean_absolute_error: 2.6787
# Epoch 18/100
# 21/21 [==============================] - 0s 14ms/step - loss: 13.1027 - mean_absolute_error: 2.5538 - val_loss: 18.8554 - val_mean_absolute_error: 2.6370
# Epoch 19/100
# 21/21 [==============================] - 0s 12ms/step - loss: 12.6553 - mean_absolute_error: 2.5383 - val_loss: 18.2307 - val_mean_absolute_error: 2.5966
# Epoch 20/100
# 21/21 [==============================] - 0s 5ms/step - loss: 12.1425 - mean_absolute_error: 2.4754 - val_loss: 18.1073 - val_mean_absolute_error: 2.5791
# Epoch 21/100
# 21/21 [==============================] - 0s 5ms/step - loss: 11.7088 - mean_absolute_error: 2.4499 - val_loss: 17.6920 - val_mean_absolute_error: 2.5677
# Epoch 22/100
# 21/21 [==============================] - 0s 10ms/step - loss: 11.3501 - mean_absolute_error: 2.4330 - val_loss: 17.4024 - val_mean_absolute_error: 2.5577
# Epoch 23/100
# 21/21 [==============================] - 0s 10ms/step - loss: 11.0652 - mean_absolute_error: 2.3858 - val_loss: 17.1798 - val_mean_absolute_error: 2.5388
# Epoch 24/100
# 21/21 [==============================] - 0s 13ms/step - loss: 10.7907 - mean_absolute_error: 2.3522 - val_loss: 16.9311 - val_mean_absolute_error: 2.5325
# Epoch 25/100
# 21/21 [==============================] - 0s 10ms/step - loss: 10.5722 - mean_absolute_error: 2.3319 - val_loss: 16.6202 - val_mean_absolute_error: 2.5268
# Epoch 26/100
# 21/21 [==============================] - 0s 13ms/step - loss: 10.3069 - mean_absolute_error: 2.3089 - val_loss: 16.3866 - val_mean_absolute_error: 2.5075
# Epoch 27/100
# 21/21 [==============================] - 0s 11ms/step - loss: 9.9983 - mean_absolute_error: 2.2919 - val_loss: 16.1012 - val_mean_absolute_error: 2.5046
# Epoch 28/100
# 21/21 [==============================] - 0s 14ms/step - loss: 9.8880 - mean_absolute_error: 2.2759 - val_loss: 16.0683 - val_mean_absolute_error: 2.4980
# Epoch 29/100
# 21/21 [==============================] - 0s 8ms/step - loss: 9.7608 - mean_absolute_error: 2.2461 - val_loss: 16.3354 - val_mean_absolute_error: 2.5267
# Epoch 30/100
# 21/21 [==============================] - 0s 9ms/step - loss: 9.4776 - mean_absolute_error: 2.2121 - val_loss: 15.8534 - val_mean_absolute_error: 2.4962
# Epoch 31/100
# 21/21 [==============================] - 0s 8ms/step - loss: 9.3915 - mean_absolute_error: 2.2019 - val_loss: 15.7550 - val_mean_absolute_error: 2.5078
# Epoch 32/100
# 21/21 [==============================] - 0s 7ms/step - loss: 9.2642 - mean_absolute_error: 2.1989 - val_loss: 15.8107 - val_mean_absolute_error: 2.5141
# Epoch 33/100
# 21/21 [==============================] - 0s 14ms/step - loss: 9.1526 - mean_absolute_error: 2.1674 - val_loss: 15.5677 - val_mean_absolute_error: 2.4954
# Epoch 34/100
# 21/21 [==============================] - 0s 16ms/step - loss: 9.1027 - mean_absolute_error: 2.1638 - val_loss: 15.4828 - val_mean_absolute_error: 2.4793
# Epoch 35/100
# 21/21 [==============================] - 0s 12ms/step - loss: 8.9907 - mean_absolute_error: 2.1619 - val_loss: 15.9112 - val_mean_absolute_error: 2.5276
# Epoch 36/100
# 21/21 [==============================] - 0s 12ms/step - loss: 8.7817 - mean_absolute_error: 2.1582 - val_loss: 15.3453 - val_mean_absolute_error: 2.4985
# Epoch 37/100
# 21/21 [==============================] - 0s 13ms/step - loss: 8.6987 - mean_absolute_error: 2.1234 - val_loss: 15.4530 - val_mean_absolute_error: 2.4749
# Epoch 38/100
# 21/21 [==============================] - 0s 9ms/step - loss: 8.6615 - mean_absolute_error: 2.1343 - val_loss: 15.3747 - val_mean_absolute_error: 2.4836
# Epoch 39/100
# 21/21 [==============================] - 0s 12ms/step - loss: 8.6023 - mean_absolute_error: 2.1327 - val_loss: 15.0813 - val_mean_absolute_error: 2.4694
# Epoch 40/100
# 21/21 [==============================] - 0s 9ms/step - loss: 8.4897 - mean_absolute_error: 2.0875 - val_loss: 14.9906 - val_mean_absolute_error: 2.4677
# Epoch 41/100
# 21/21 [==============================] - 0s 9ms/step - loss: 8.3939 - mean_absolute_error: 2.1007 - val_loss: 15.0396 - val_mean_absolute_error: 2.4704
# Epoch 42/100
# 21/21 [==============================] - 0s 11ms/step - loss: 8.3340 - mean_absolute_error: 2.1115 - val_loss: 15.3424 - val_mean_absolute_error: 2.5165
# Epoch 43/100
# 21/21 [==============================] - 0s 9ms/step - loss: 8.2155 - mean_absolute_error: 2.0765 - val_loss: 14.8205 - val_mean_absolute_error: 2.4689
# Epoch 44/100
# 21/21 [==============================] - 0s 8ms/step - loss: 8.1165 - mean_absolute_error: 2.0599 - val_loss: 14.9259 - val_mean_absolute_error: 2.4631
# Epoch 45/100
# 21/21 [==============================] - 0s 10ms/step - loss: 8.0792 - mean_absolute_error: 2.0922 - val_loss: 14.8958 - val_mean_absolute_error: 2.4572
# Epoch 46/100
# 21/21 [==============================] - 0s 6ms/step - loss: 7.8930 - mean_absolute_error: 2.0466 - val_loss: 14.8739 - val_mean_absolute_error: 2.4821
# Epoch 47/100
# 21/21 [==============================] - 0s 8ms/step - loss: 8.0532 - mean_absolute_error: 2.0771 - val_loss: 14.7785 - val_mean_absolute_error: 2.4503
# Epoch 48/100
# 21/21 [==============================] - 0s 9ms/step - loss: 7.8548 - mean_absolute_error: 2.0456 - val_loss: 14.9521 - val_mean_absolute_error: 2.5100
# Epoch 49/100
# 21/21 [==============================] - 0s 9ms/step - loss: 7.8760 - mean_absolute_error: 2.0703 - val_loss: 14.8574 - val_mean_absolute_error: 2.4719
# Epoch 50/100
# 21/21 [==============================] - 0s 9ms/step - loss: 7.8538 - mean_absolute_error: 2.0410 - val_loss: 14.6834 - val_mean_absolute_error: 2.4717
# Epoch 51/100
# 21/21 [==============================] - 0s 10ms/step - loss: 7.6394 - mean_absolute_error: 2.0247 - val_loss: 14.7026 - val_mean_absolute_error: 2.4819
# Epoch 52/100
# 21/21 [==============================] - 0s 6ms/step - loss: 7.5544 - mean_absolute_error: 2.0098 - val_loss: 14.9377 - val_mean_absolute_error: 2.4842
# Epoch 53/100
# 21/21 [==============================] - 0s 7ms/step - loss: 7.4434 - mean_absolute_error: 2.0011 - val_loss: 14.5722 - val_mean_absolute_error: 2.4599
# Epoch 54/100
# 21/21 [==============================] - 0s 9ms/step - loss: 7.3513 - mean_absolute_error: 1.9778 - val_loss: 14.5021 - val_mean_absolute_error: 2.4758
# Epoch 55/100
# 21/21 [==============================] - 0s 6ms/step - loss: 7.3009 - mean_absolute_error: 1.9716 - val_loss: 14.3864 - val_mean_absolute_error: 2.4585
# Epoch 56/100
# 21/21 [==============================] - 0s 5ms/step - loss: 7.4034 - mean_absolute_error: 2.0119 - val_loss: 14.5960 - val_mean_absolute_error: 2.4637
# Epoch 57/100
# 21/21 [==============================] - 0s 8ms/step - loss: 7.3745 - mean_absolute_error: 1.9731 - val_loss: 14.3024 - val_mean_absolute_error: 2.4643
# Epoch 58/100
# 21/21 [==============================] - 0s 14ms/step - loss: 7.1859 - mean_absolute_error: 1.9811 - val_loss: 14.4592 - val_mean_absolute_error: 2.4947
# Epoch 59/100
# 21/21 [==============================] - 0s 11ms/step - loss: 7.2836 - mean_absolute_error: 1.9721 - val_loss: 14.3569 - val_mean_absolute_error: 2.4322
# Epoch 60/100
# 21/21 [==============================] - 0s 10ms/step - loss: 7.1468 - mean_absolute_error: 1.9707 - val_loss: 14.4160 - val_mean_absolute_error: 2.4564
# Epoch 61/100
# 21/21 [==============================] - 0s 9ms/step - loss: 7.0202 - mean_absolute_error: 1.9518 - val_loss: 14.2344 - val_mean_absolute_error: 2.4707
# Epoch 62/100
# 21/21 [==============================] - 0s 12ms/step - loss: 7.1000 - mean_absolute_error: 1.9540 - val_loss: 14.2733 - val_mean_absolute_error: 2.4270
# Epoch 63/100
# 21/21 [==============================] - 0s 11ms/step - loss: 6.9459 - mean_absolute_error: 1.9327 - val_loss: 14.1675 - val_mean_absolute_error: 2.4523
# Epoch 64/100
# 21/21 [==============================] - 0s 13ms/step - loss: 6.8422 - mean_absolute_error: 1.9354 - val_loss: 14.3620 - val_mean_absolute_error: 2.4540
# Epoch 65/100
# 21/21 [==============================] - 0s 8ms/step - loss: 6.9559 - mean_absolute_error: 1.9222 - val_loss: 14.0596 - val_mean_absolute_error: 2.4477
# Epoch 66/100
# 21/21 [==============================] - 0s 11ms/step - loss: 6.7875 - mean_absolute_error: 1.9147 - val_loss: 14.1000 - val_mean_absolute_error: 2.4510
# Epoch 67/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.7541 - mean_absolute_error: 1.9132 - val_loss: 13.8308 - val_mean_absolute_error: 2.4358
# Epoch 68/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.6560 - mean_absolute_error: 1.8859 - val_loss: 14.0564 - val_mean_absolute_error: 2.4547
# Epoch 69/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.6682 - mean_absolute_error: 1.9091 - val_loss: 13.9133 - val_mean_absolute_error: 2.4569
# Epoch 70/100
# 21/21 [==============================] - 0s 6ms/step - loss: 6.6617 - mean_absolute_error: 1.9225 - val_loss: 13.7045 - val_mean_absolute_error: 2.4214
# Epoch 71/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.4726 - mean_absolute_error: 1.8773 - val_loss: 13.9469 - val_mean_absolute_error: 2.4217
# Epoch 72/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.4872 - mean_absolute_error: 1.8748 - val_loss: 13.6910 - val_mean_absolute_error: 2.4592
# Epoch 73/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.9254 - mean_absolute_error: 1.9675 - val_loss: 14.3573 - val_mean_absolute_error: 2.5430
# Epoch 74/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.6095 - mean_absolute_error: 1.9165 - val_loss: 14.0292 - val_mean_absolute_error: 2.4751
# Epoch 75/100
# 21/21 [==============================] - 0s 6ms/step - loss: 6.4654 - mean_absolute_error: 1.8656 - val_loss: 13.8770 - val_mean_absolute_error: 2.4139
# Epoch 76/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.3798 - mean_absolute_error: 1.8655 - val_loss: 14.0551 - val_mean_absolute_error: 2.5343
# Epoch 77/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.5913 - mean_absolute_error: 1.9017 - val_loss: 13.7684 - val_mean_absolute_error: 2.4410
# Epoch 78/100
# 21/21 [==============================] - 0s 5ms/step - loss: 7.2365 - mean_absolute_error: 2.0111 - val_loss: 14.9849 - val_mean_absolute_error: 2.7501
# Epoch 79/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.4813 - mean_absolute_error: 1.9093 - val_loss: 13.8538 - val_mean_absolute_error: 2.4732
# Epoch 80/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.4237 - mean_absolute_error: 1.8553 - val_loss: 13.6994 - val_mean_absolute_error: 2.4478
# Epoch 81/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.3726 - mean_absolute_error: 1.8762 - val_loss: 13.7722 - val_mean_absolute_error: 2.4846
# Epoch 82/100
# 21/21 [==============================] - 0s 6ms/step - loss: 6.4288 - mean_absolute_error: 1.9121 - val_loss: 13.3709 - val_mean_absolute_error: 2.4092
# Epoch 83/100
# 21/21 [==============================] - 0s 5ms/step - loss: 5.9749 - mean_absolute_error: 1.8063 - val_loss: 13.9447 - val_mean_absolute_error: 2.4856
# Epoch 84/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.0731 - mean_absolute_error: 1.8269 - val_loss: 13.5115 - val_mean_absolute_error: 2.4618
# Epoch 85/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.0788 - mean_absolute_error: 1.8331 - val_loss: 13.6509 - val_mean_absolute_error: 2.4351
# Epoch 86/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.0425 - mean_absolute_error: 1.8278 - val_loss: 13.7590 - val_mean_absolute_error: 2.5043
# Epoch 87/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.1619 - mean_absolute_error: 1.8359 - val_loss: 13.4889 - val_mean_absolute_error: 2.4059
# Epoch 88/100
# 21/21 [==============================] - 0s 5ms/step - loss: 5.8705 - mean_absolute_error: 1.8098 - val_loss: 13.6186 - val_mean_absolute_error: 2.3907
# Epoch 89/100
# 21/21 [==============================] - 0s 4ms/step - loss: 5.8915 - mean_absolute_error: 1.8003 - val_loss: 13.4723 - val_mean_absolute_error: 2.4445
# Epoch 90/100
# 21/21 [==============================] - 0s 5ms/step - loss: 5.8862 - mean_absolute_error: 1.8074 - val_loss: 13.2383 - val_mean_absolute_error: 2.3804
# Epoch 91/100
# 21/21 [==============================] - 0s 4ms/step - loss: 5.8282 - mean_absolute_error: 1.7765 - val_loss: 13.3625 - val_mean_absolute_error: 2.4221
# Epoch 92/100
# 21/21 [==============================] - 0s 4ms/step - loss: 5.8797 - mean_absolute_error: 1.8339 - val_loss: 13.4305 - val_mean_absolute_error: 2.4474
# Epoch 93/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.0643 - mean_absolute_error: 1.8297 - val_loss: 13.2831 - val_mean_absolute_error: 2.4279
# Epoch 94/100
# 21/21 [==============================] - 0s 5ms/step - loss: 5.7468 - mean_absolute_error: 1.7578 - val_loss: 13.4729 - val_mean_absolute_error: 2.4113
# Epoch 95/100
# 21/21 [==============================] - 0s 4ms/step - loss: 5.6243 - mean_absolute_error: 1.7556 - val_loss: 13.1386 - val_mean_absolute_error: 2.3941
# Epoch 96/100
# 21/21 [==============================] - 0s 4ms/step - loss: 5.5682 - mean_absolute_error: 1.7449 - val_loss: 13.2717 - val_mean_absolute_error: 2.4500
# Epoch 97/100
# 21/21 [==============================] - 0s 4ms/step - loss: 5.8346 - mean_absolute_error: 1.7925 - val_loss: 13.1252 - val_mean_absolute_error: 2.4025
# Epoch 98/100
# 21/21 [==============================] - 0s 4ms/step - loss: 5.6428 - mean_absolute_error: 1.7738 - val_loss: 13.1634 - val_mean_absolute_error: 2.3871
# Epoch 99/100
# 21/21 [==============================] - 0s 5ms/step - loss: 5.7014 - mean_absolute_error: 1.7860 - val_loss: 12.7608 - val_mean_absolute_error: 2.3738
# Epoch 100/100
# 21/21 [==============================] - 0s 5ms/step - loss: 5.4255 - mean_absolute_error: 1.7423 - val_loss: 12.7490 - val_mean_absolute_error: 2.3621

# %%
history.history.keys()  # 查看history儲存的資訊有哪些
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.title('Mean square error')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')

# %%
plt.plot(history.history['mean_absolute_error'], label='train')
plt.plot(history.history['val_mean_absolute_error'], label='validation')
plt.title('Mean absolute error')
plt.ylabel('metrics')
plt.xlabel('epochs')
plt.legend(loc='upper right')

# %%
model = keras.models.load_model('lab1-logs/models/Best-model-1.keras')

# 預測測試數據
y_pred = model.predict(test_data)
print(y_pred.shape)
print(test_targets.shape)

# 不需要將預測結果轉換回來(因為訓練時的訓練目標並沒有經過標準化)
# y_pred = np.reshape(y_pred * std['price'] + mean['price'], y_test.shape)

y_pred = np.reshape(y_pred, test_targets.shape)
print(y_pred.shape, test_targets.shape)
# 計算平均的誤差百分比
percentage_error = np.mean(np.abs(test_targets - y_pred) / test_targets) * 100
# 顯示誤差百分比
print("Model_1 Percentage Error: {:.2f}%".format(percentage_error))
# Out:
# 4/4 [==============================] - 0s 3ms/step
# (102, 1)
# (102,)
# (102,) (102,)
# Model_1 Percentage Error: 13.63%

# %% [markdown]
# 實驗二：過擬合問題
#
# 方法一、減少網路權重(減少神經元)

# %%
model_2 = keras.Sequential(name='model-2')
model_2.add(layers.Dense(16, activation='relu', input_shape=(13,)))
model_2.add(layers.Dense(16, activation='relu'))
model_2.add(layers.Dense(1))

model_2.compile(keras.optimizers.Adam(0.001),
                loss=keras.losses.MeanSquaredError(),
                metrics=[keras.metrics.MeanAbsoluteError()])

log_dir = os.path.join('lab1-logs', 'model-2')
model_cbk = keras.callbacks.TensorBoard(log_dir=log_dir)
model_mckp = keras.callbacks.ModelCheckpoint(model_dir + '/Best-model-2.keras',
                                             monitor='val_mean_absolute_error',
                                             save_best_only=True,
                                             mode='min')
es = keras.callbacks.EarlyStopping(monitor='val_mean_absolute_error', mode='min', patience=10)
model_2.fit(train_data, train_targets,  # 傳入訓練數據
               batch_size=16,  # 批次大小設為16
               epochs=100,  # 整個dataset訓練100遍
               validation_data=(val_data, val_targets),  # 驗證數據
               callbacks=[model_cbk, model_mckp, es])  # Tensorboard回調函數紀錄訓練過程，ModelCheckpoint回調函數儲存最好的模型
# Out:
# Epoch 1/100
# 21/21 [==============================] - 1s 10ms/step - loss: 526.3845 - mean_absolute_error: 20.7155 - val_loss: 537.5537 - val_mean_absolute_error: 21.2311
# Epoch 2/100
# 21/21 [==============================] - 0s 5ms/step - loss: 497.6250 - mean_absolute_error: 19.9457 - val_loss: 506.3358 - val_mean_absolute_error: 20.4478
# Epoch 3/100
# 21/21 [==============================] - 0s 5ms/step - loss: 463.5217 - mean_absolute_error: 19.0240 - val_loss: 465.2427 - val_mean_absolute_error: 19.4017
# Epoch 4/100
# 21/21 [==============================] - 0s 5ms/step - loss: 418.8663 - mean_absolute_error: 17.8801 - val_loss: 410.8989 - val_mean_absolute_error: 18.0642
# Epoch 5/100
# 21/21 [==============================] - 0s 5ms/step - loss: 361.0105 - mean_absolute_error: 16.3848 - val_loss: 341.2780 - val_mean_absolute_error: 16.2370
# Epoch 6/100
# 21/21 [==============================] - 0s 5ms/step - loss: 289.4609 - mean_absolute_error: 14.3607 - val_loss: 254.8513 - val_mean_absolute_error: 13.7175
# Epoch 7/100
# 21/21 [==============================] - 0s 5ms/step - loss: 210.4190 - mean_absolute_error: 11.9414 - val_loss: 175.6698 - val_mean_absolute_error: 10.8914
# Epoch 8/100
# 21/21 [==============================] - 0s 5ms/step - loss: 144.8461 - mean_absolute_error: 9.5769 - val_loss: 120.7811 - val_mean_absolute_error: 8.4187
# Epoch 9/100
# 21/21 [==============================] - 0s 5ms/step - loss: 101.6025 - mean_absolute_error: 7.8472 - val_loss: 89.9073 - val_mean_absolute_error: 7.1685
# Epoch 10/100
# 21/21 [==============================] - 0s 5ms/step - loss: 77.6035 - mean_absolute_error: 6.8120 - val_loss: 73.4025 - val_mean_absolute_error: 6.5209
# Epoch 11/100
# 21/21 [==============================] - 0s 5ms/step - loss: 63.3653 - mean_absolute_error: 6.1129 - val_loss: 61.6397 - val_mean_absolute_error: 5.8859
# Epoch 12/100
# 21/21 [==============================] - 0s 6ms/step - loss: 52.1634 - mean_absolute_error: 5.5563 - val_loss: 53.3838 - val_mean_absolute_error: 5.3404
# Epoch 13/100
# 21/21 [==============================] - 0s 6ms/step - loss: 44.0479 - mean_absolute_error: 5.0667 - val_loss: 45.7607 - val_mean_absolute_error: 4.8392
# Epoch 14/100
# 21/21 [==============================] - 0s 5ms/step - loss: 38.1435 - mean_absolute_error: 4.6636 - val_loss: 41.0892 - val_mean_absolute_error: 4.5103
# Epoch 15/100
# 21/21 [==============================] - 0s 5ms/step - loss: 34.0479 - mean_absolute_error: 4.3781 - val_loss: 37.5631 - val_mean_absolute_error: 4.2377
# Epoch 16/100
# 21/21 [==============================] - 0s 5ms/step - loss: 31.0914 - mean_absolute_error: 4.1689 - val_loss: 34.8554 - val_mean_absolute_error: 4.0302
# Epoch 17/100
# 21/21 [==============================] - 0s 5ms/step - loss: 28.7086 - mean_absolute_error: 4.0029 - val_loss: 32.8181 - val_mean_absolute_error: 3.8675
# Epoch 18/100
# 21/21 [==============================] - 0s 6ms/step - loss: 27.0588 - mean_absolute_error: 3.8650 - val_loss: 31.2687 - val_mean_absolute_error: 3.7355
# Epoch 19/100
# 21/21 [==============================] - 0s 6ms/step - loss: 25.7768 - mean_absolute_error: 3.7489 - val_loss: 30.2917 - val_mean_absolute_error: 3.5805
# Epoch 20/100
# 21/21 [==============================] - 0s 5ms/step - loss: 24.7431 - mean_absolute_error: 3.6606 - val_loss: 28.9329 - val_mean_absolute_error: 3.5474
# Epoch 21/100
# 21/21 [==============================] - 0s 5ms/step - loss: 23.5697 - mean_absolute_error: 3.5752 - val_loss: 28.1892 - val_mean_absolute_error: 3.4816
# Epoch 22/100
# 21/21 [==============================] - 0s 5ms/step - loss: 22.8976 - mean_absolute_error: 3.5213 - val_loss: 27.3837 - val_mean_absolute_error: 3.4161
# Epoch 23/100
# 21/21 [==============================] - 0s 5ms/step - loss: 21.9820 - mean_absolute_error: 3.4567 - val_loss: 26.6013 - val_mean_absolute_error: 3.4040
# Epoch 24/100
# 21/21 [==============================] - 0s 5ms/step - loss: 21.3935 - mean_absolute_error: 3.4174 - val_loss: 26.0539 - val_mean_absolute_error: 3.3577
# Epoch 25/100
# 21/21 [==============================] - 0s 5ms/step - loss: 20.8229 - mean_absolute_error: 3.3636 - val_loss: 25.6650 - val_mean_absolute_error: 3.2969
# Epoch 26/100
# 21/21 [==============================] - 0s 5ms/step - loss: 20.3526 - mean_absolute_error: 3.3094 - val_loss: 25.2163 - val_mean_absolute_error: 3.2622
# Epoch 27/100
# 21/21 [==============================] - 0s 8ms/step - loss: 19.8729 - mean_absolute_error: 3.2701 - val_loss: 24.8088 - val_mean_absolute_error: 3.2288
# Epoch 28/100
# 21/21 [==============================] - 0s 9ms/step - loss: 19.3693 - mean_absolute_error: 3.2498 - val_loss: 24.2662 - val_mean_absolute_error: 3.2285
# Epoch 29/100
# 21/21 [==============================] - 0s 9ms/step - loss: 18.9391 - mean_absolute_error: 3.2106 - val_loss: 23.9918 - val_mean_absolute_error: 3.1943
# Epoch 30/100
# 21/21 [==============================] - 0s 7ms/step - loss: 18.5802 - mean_absolute_error: 3.1585 - val_loss: 23.6983 - val_mean_absolute_error: 3.1568
# Epoch 31/100
# 21/21 [==============================] - 0s 7ms/step - loss: 18.1586 - mean_absolute_error: 3.1241 - val_loss: 23.4444 - val_mean_absolute_error: 3.1214
# Epoch 32/100
# 21/21 [==============================] - 0s 7ms/step - loss: 17.8212 - mean_absolute_error: 3.0885 - val_loss: 23.2614 - val_mean_absolute_error: 3.0921
# Epoch 33/100
# 21/21 [==============================] - 0s 7ms/step - loss: 17.4542 - mean_absolute_error: 3.0401 - val_loss: 22.9379 - val_mean_absolute_error: 3.0690
# Epoch 34/100
# 21/21 [==============================] - 0s 7ms/step - loss: 17.0976 - mean_absolute_error: 3.0195 - val_loss: 22.5852 - val_mean_absolute_error: 3.0501
# Epoch 35/100
# 21/21 [==============================] - 0s 9ms/step - loss: 16.7247 - mean_absolute_error: 2.9868 - val_loss: 22.3992 - val_mean_absolute_error: 3.0170
# Epoch 36/100
# 21/21 [==============================] - 0s 7ms/step - loss: 16.4919 - mean_absolute_error: 2.9608 - val_loss: 22.0683 - val_mean_absolute_error: 3.0138
# Epoch 37/100
# 21/21 [==============================] - 0s 7ms/step - loss: 16.2303 - mean_absolute_error: 2.9173 - val_loss: 22.0958 - val_mean_absolute_error: 2.9599
# Epoch 38/100
# 21/21 [==============================] - 0s 7ms/step - loss: 16.0424 - mean_absolute_error: 2.9320 - val_loss: 21.2918 - val_mean_absolute_error: 2.9518
# Epoch 39/100
# 21/21 [==============================] - 0s 7ms/step - loss: 15.4483 - mean_absolute_error: 2.8681 - val_loss: 21.4055 - val_mean_absolute_error: 2.9171
# Epoch 40/100
# 21/21 [==============================] - 0s 7ms/step - loss: 15.2758 - mean_absolute_error: 2.8211 - val_loss: 21.1700 - val_mean_absolute_error: 2.9065
# Epoch 41/100
# 21/21 [==============================] - 0s 5ms/step - loss: 14.8646 - mean_absolute_error: 2.8075 - val_loss: 20.6869 - val_mean_absolute_error: 2.8986
# Epoch 42/100
# 21/21 [==============================] - 0s 5ms/step - loss: 14.5843 - mean_absolute_error: 2.7777 - val_loss: 20.5306 - val_mean_absolute_error: 2.8885
# Epoch 43/100
# 21/21 [==============================] - 0s 5ms/step - loss: 14.3483 - mean_absolute_error: 2.7595 - val_loss: 20.3195 - val_mean_absolute_error: 2.8499
# Epoch 44/100
# 21/21 [==============================] - 0s 5ms/step - loss: 14.1075 - mean_absolute_error: 2.7257 - val_loss: 20.1099 - val_mean_absolute_error: 2.8366
# Epoch 45/100
# 21/21 [==============================] - 0s 5ms/step - loss: 13.8530 - mean_absolute_error: 2.7132 - val_loss: 19.6029 - val_mean_absolute_error: 2.8488
# Epoch 46/100
# 21/21 [==============================] - 0s 6ms/step - loss: 13.6864 - mean_absolute_error: 2.6849 - val_loss: 19.7134 - val_mean_absolute_error: 2.8023
# Epoch 47/100
# 21/21 [==============================] - 0s 5ms/step - loss: 13.3477 - mean_absolute_error: 2.6472 - val_loss: 19.3857 - val_mean_absolute_error: 2.7808
# Epoch 48/100
# 21/21 [==============================] - 0s 6ms/step - loss: 13.2266 - mean_absolute_error: 2.6512 - val_loss: 19.1793 - val_mean_absolute_error: 2.7749
# Epoch 49/100
# 21/21 [==============================] - 0s 5ms/step - loss: 12.9840 - mean_absolute_error: 2.6163 - val_loss: 19.2120 - val_mean_absolute_error: 2.7692
# Epoch 50/100
# 21/21 [==============================] - 0s 5ms/step - loss: 12.7558 - mean_absolute_error: 2.5981 - val_loss: 18.9180 - val_mean_absolute_error: 2.7571
# Epoch 51/100
# 21/21 [==============================] - 0s 5ms/step - loss: 12.6516 - mean_absolute_error: 2.5813 - val_loss: 18.7716 - val_mean_absolute_error: 2.7376
# Epoch 52/100
# 21/21 [==============================] - 0s 5ms/step - loss: 12.4368 - mean_absolute_error: 2.5646 - val_loss: 18.6119 - val_mean_absolute_error: 2.7231
# Epoch 53/100
# 21/21 [==============================] - 0s 4ms/step - loss: 12.3172 - mean_absolute_error: 2.5578 - val_loss: 18.4226 - val_mean_absolute_error: 2.7331
# Epoch 54/100
# 21/21 [==============================] - 0s 6ms/step - loss: 12.1708 - mean_absolute_error: 2.5363 - val_loss: 18.3275 - val_mean_absolute_error: 2.7161
# Epoch 55/100
# 21/21 [==============================] - 0s 5ms/step - loss: 12.0757 - mean_absolute_error: 2.5395 - val_loss: 18.0753 - val_mean_absolute_error: 2.7279
# Epoch 56/100
# 21/21 [==============================] - 0s 5ms/step - loss: 11.8620 - mean_absolute_error: 2.5155 - val_loss: 18.0402 - val_mean_absolute_error: 2.7039
# Epoch 57/100
# 21/21 [==============================] - 0s 6ms/step - loss: 11.8250 - mean_absolute_error: 2.5116 - val_loss: 18.2955 - val_mean_absolute_error: 2.6999
# Epoch 58/100
# 21/21 [==============================] - 0s 6ms/step - loss: 11.6466 - mean_absolute_error: 2.4947 - val_loss: 18.0077 - val_mean_absolute_error: 2.6862
# Epoch 59/100
# 21/21 [==============================] - 0s 5ms/step - loss: 11.5000 - mean_absolute_error: 2.4803 - val_loss: 17.6725 - val_mean_absolute_error: 2.7047
# Epoch 60/100
# 21/21 [==============================] - 0s 5ms/step - loss: 11.3710 - mean_absolute_error: 2.4828 - val_loss: 17.5938 - val_mean_absolute_error: 2.7156
# Epoch 61/100
# 21/21 [==============================] - 0s 4ms/step - loss: 11.2699 - mean_absolute_error: 2.4653 - val_loss: 17.5652 - val_mean_absolute_error: 2.6899
# Epoch 62/100
# 21/21 [==============================] - 0s 6ms/step - loss: 11.2840 - mean_absolute_error: 2.4658 - val_loss: 17.4312 - val_mean_absolute_error: 2.6816
# Epoch 63/100
# 21/21 [==============================] - 0s 5ms/step - loss: 11.1882 - mean_absolute_error: 2.4451 - val_loss: 17.5428 - val_mean_absolute_error: 2.6719
# Epoch 64/100
# 21/21 [==============================] - 0s 4ms/step - loss: 11.1002 - mean_absolute_error: 2.4484 - val_loss: 16.8833 - val_mean_absolute_error: 2.7031
# Epoch 65/100
# 21/21 [==============================] - 0s 4ms/step - loss: 10.8852 - mean_absolute_error: 2.4424 - val_loss: 16.9330 - val_mean_absolute_error: 2.6732
# Epoch 66/100
# 21/21 [==============================] - 0s 5ms/step - loss: 10.7140 - mean_absolute_error: 2.4120 - val_loss: 16.9796 - val_mean_absolute_error: 2.6535
# Epoch 67/100
# 21/21 [==============================] - 0s 5ms/step - loss: 10.7133 - mean_absolute_error: 2.4120 - val_loss: 17.0800 - val_mean_absolute_error: 2.6603
# Epoch 68/100
# 21/21 [==============================] - 0s 5ms/step - loss: 10.6024 - mean_absolute_error: 2.4015 - val_loss: 16.8107 - val_mean_absolute_error: 2.6761
# Epoch 69/100
# 21/21 [==============================] - 0s 5ms/step - loss: 10.5991 - mean_absolute_error: 2.3920 - val_loss: 16.9835 - val_mean_absolute_error: 2.6536
# Epoch 70/100
# 21/21 [==============================] - 0s 5ms/step - loss: 10.4874 - mean_absolute_error: 2.3811 - val_loss: 16.6258 - val_mean_absolute_error: 2.6793
# Epoch 71/100
# 21/21 [==============================] - 0s 5ms/step - loss: 10.5126 - mean_absolute_error: 2.3718 - val_loss: 16.8789 - val_mean_absolute_error: 2.6419
# Epoch 72/100
# 21/21 [==============================] - 0s 4ms/step - loss: 10.3419 - mean_absolute_error: 2.3700 - val_loss: 16.8747 - val_mean_absolute_error: 2.6547
# Epoch 73/100
# 21/21 [==============================] - 0s 5ms/step - loss: 10.2336 - mean_absolute_error: 2.3621 - val_loss: 16.7083 - val_mean_absolute_error: 2.6562
# Epoch 74/100
# 21/21 [==============================] - 0s 4ms/step - loss: 10.1645 - mean_absolute_error: 2.3626 - val_loss: 16.5689 - val_mean_absolute_error: 2.6757
# Epoch 75/100
# 21/21 [==============================] - 0s 4ms/step - loss: 10.0918 - mean_absolute_error: 2.3520 - val_loss: 16.5786 - val_mean_absolute_error: 2.6527
# Epoch 76/100
# 21/21 [==============================] - 0s 4ms/step - loss: 10.0786 - mean_absolute_error: 2.3417 - val_loss: 16.7908 - val_mean_absolute_error: 2.6550
# Epoch 77/100
# 21/21 [==============================] - 0s 4ms/step - loss: 10.0582 - mean_absolute_error: 2.3609 - val_loss: 16.1140 - val_mean_absolute_error: 2.6756
# Epoch 78/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.9460 - mean_absolute_error: 2.3475 - val_loss: 16.2358 - val_mean_absolute_error: 2.6408
# Epoch 79/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.8450 - mean_absolute_error: 2.3280 - val_loss: 16.2374 - val_mean_absolute_error: 2.6369
# Epoch 80/100
# 21/21 [==============================] - 0s 4ms/step - loss: 9.8369 - mean_absolute_error: 2.3336 - val_loss: 16.1715 - val_mean_absolute_error: 2.6465
# Epoch 81/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.8305 - mean_absolute_error: 2.3177 - val_loss: 16.3832 - val_mean_absolute_error: 2.6301
# Epoch 82/100
# 21/21 [==============================] - 0s 6ms/step - loss: 9.7463 - mean_absolute_error: 2.3160 - val_loss: 16.1489 - val_mean_absolute_error: 2.6259
# Epoch 83/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.6599 - mean_absolute_error: 2.2967 - val_loss: 16.3347 - val_mean_absolute_error: 2.6246
# Epoch 84/100
# 21/21 [==============================] - 0s 4ms/step - loss: 9.7808 - mean_absolute_error: 2.3179 - val_loss: 16.3090 - val_mean_absolute_error: 2.6439
# Epoch 85/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.6411 - mean_absolute_error: 2.3097 - val_loss: 16.3266 - val_mean_absolute_error: 2.6588
# Epoch 86/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.6207 - mean_absolute_error: 2.3093 - val_loss: 16.1885 - val_mean_absolute_error: 2.6457
# Epoch 87/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.5878 - mean_absolute_error: 2.3083 - val_loss: 16.0098 - val_mean_absolute_error: 2.6389
# Epoch 88/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.5081 - mean_absolute_error: 2.2948 - val_loss: 15.9219 - val_mean_absolute_error: 2.6278
# Epoch 89/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.4861 - mean_absolute_error: 2.2852 - val_loss: 16.1500 - val_mean_absolute_error: 2.6113
# Epoch 90/100
# 21/21 [==============================] - 0s 4ms/step - loss: 9.4760 - mean_absolute_error: 2.2762 - val_loss: 15.9005 - val_mean_absolute_error: 2.6153
# Epoch 91/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.4122 - mean_absolute_error: 2.2788 - val_loss: 15.8443 - val_mean_absolute_error: 2.6152
# Epoch 92/100
# 21/21 [==============================] - 0s 6ms/step - loss: 9.3152 - mean_absolute_error: 2.2714 - val_loss: 15.7688 - val_mean_absolute_error: 2.6036
# Epoch 93/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.3405 - mean_absolute_error: 2.2666 - val_loss: 15.7943 - val_mean_absolute_error: 2.6003
# Epoch 94/100
# 21/21 [==============================] - 0s 4ms/step - loss: 9.3945 - mean_absolute_error: 2.2944 - val_loss: 15.2733 - val_mean_absolute_error: 2.6140
# Epoch 95/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.2370 - mean_absolute_error: 2.2828 - val_loss: 15.5377 - val_mean_absolute_error: 2.6084
# Epoch 96/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.2310 - mean_absolute_error: 2.2627 - val_loss: 15.5141 - val_mean_absolute_error: 2.5973
# Epoch 97/100
# 21/21 [==============================] - 0s 4ms/step - loss: 9.1600 - mean_absolute_error: 2.2609 - val_loss: 15.5283 - val_mean_absolute_error: 2.5974
# Epoch 98/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.1556 - mean_absolute_error: 2.2611 - val_loss: 15.3917 - val_mean_absolute_error: 2.5900
# Epoch 99/100
# 21/21 [==============================] - 0s 4ms/step - loss: 9.0528 - mean_absolute_error: 2.2478 - val_loss: 15.5281 - val_mean_absolute_error: 2.5922
# Epoch 100/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.1084 - mean_absolute_error: 2.2466 - val_loss: 15.3449 - val_mean_absolute_error: 2.5751

# %%
model_3 = keras.Sequential(name='model-3')
model_3.add(layers.Dense(64, kernel_regularizer=keras.regularizers.l2(0.001),
                         activation='relu', input_shape=(13,)))
model_3.add(layers.Dense(64, kernel_regularizer=keras.regularizers.l2(0.001), activation='relu'))
model_3.add(layers.Dense(1))

model_3.compile(keras.optimizers.Adam(0.001),
                loss=keras.losses.MeanSquaredError(),
                metrics=[keras.metrics.MeanAbsoluteError()])

log_dir = os.path.join('lab1-logs', 'model-3')
model_cbk = keras.callbacks.TensorBoard(log_dir=log_dir)
model_mckp = keras.callbacks.ModelCheckpoint(model_dir + '/Best-model-3.keras',
                                             monitor='val_mean_absolute_error',
                                             save_best_only=True,
                                             mode='min')
es = keras.callbacks.EarlyStopping(monitor='val_mean_absolute_error', mode='min', patience=10)
model_3.fit(train_data, train_targets,  # 傳入訓練數據
               batch_size=16,  # 批次大小設為16
               epochs=100,  # 整個dataset訓練100遍
               validation_data=(val_data, val_targets),  # 驗證數據
               callbacks=[model_cbk, model_mckp, es])
# Out:
# Epoch 1/100
# 21/21 [==============================] - 1s 12ms/step - loss: 556.0255 - mean_absolute_error: 21.6696 - val_loss: 536.9326 - val_mean_absolute_error: 21.5200
# Epoch 2/100
# 21/21 [==============================] - 0s 5ms/step - loss: 473.6805 - mean_absolute_error: 19.8367 - val_loss: 432.1178 - val_mean_absolute_error: 19.1857
# Epoch 3/100
# 21/21 [==============================] - 0s 6ms/step - loss: 344.0150 - mean_absolute_error: 16.5126 - val_loss: 263.8357 - val_mean_absolute_error: 14.5844
# Epoch 4/100
# 21/21 [==============================] - 0s 6ms/step - loss: 175.1798 - mean_absolute_error: 11.0984 - val_loss: 119.6266 - val_mean_absolute_error: 8.6169
# Epoch 5/100
# 21/21 [==============================] - 0s 6ms/step - loss: 81.0384 - mean_absolute_error: 6.9575 - val_loss: 77.5849 - val_mean_absolute_error: 6.6615
# Epoch 6/100
# 21/21 [==============================] - 0s 6ms/step - loss: 53.9752 - mean_absolute_error: 5.5758 - val_loss: 54.6134 - val_mean_absolute_error: 5.3489
# Epoch 7/100
# 21/21 [==============================] - 0s 5ms/step - loss: 39.7049 - mean_absolute_error: 4.7071 - val_loss: 42.1740 - val_mean_absolute_error: 4.5156
# Epoch 8/100
# 21/21 [==============================] - 0s 6ms/step - loss: 31.2659 - mean_absolute_error: 4.1440 - val_loss: 35.8591 - val_mean_absolute_error: 3.9546
# Epoch 9/100
# 21/21 [==============================] - 0s 5ms/step - loss: 26.5139 - mean_absolute_error: 3.7702 - val_loss: 31.2615 - val_mean_absolute_error: 3.5796
# Epoch 10/100
# 21/21 [==============================] - 0s 5ms/step - loss: 23.8068 - mean_absolute_error: 3.5508 - val_loss: 28.3684 - val_mean_absolute_error: 3.3368
# Epoch 11/100
# 21/21 [==============================] - 0s 6ms/step - loss: 21.6604 - mean_absolute_error: 3.4475 - val_loss: 26.0584 - val_mean_absolute_error: 3.2382
# Epoch 12/100
# 21/21 [==============================] - 0s 5ms/step - loss: 20.0538 - mean_absolute_error: 3.2888 - val_loss: 25.7055 - val_mean_absolute_error: 3.1469
# Epoch 13/100
# 21/21 [==============================] - 0s 6ms/step - loss: 18.7970 - mean_absolute_error: 3.1450 - val_loss: 25.2049 - val_mean_absolute_error: 3.1021
# Epoch 14/100
# 21/21 [==============================] - 0s 6ms/step - loss: 17.6405 - mean_absolute_error: 3.0522 - val_loss: 23.6192 - val_mean_absolute_error: 3.0204
# Epoch 15/100
# 21/21 [==============================] - 0s 5ms/step - loss: 16.8284 - mean_absolute_error: 2.9647 - val_loss: 23.2117 - val_mean_absolute_error: 2.9838
# Epoch 16/100
# 21/21 [==============================] - 0s 5ms/step - loss: 15.7539 - mean_absolute_error: 2.8790 - val_loss: 22.2281 - val_mean_absolute_error: 2.9395
# Epoch 17/100
# 21/21 [==============================] - 0s 5ms/step - loss: 14.9869 - mean_absolute_error: 2.7996 - val_loss: 21.3599 - val_mean_absolute_error: 2.8803
# Epoch 18/100
# 21/21 [==============================] - 0s 5ms/step - loss: 14.4476 - mean_absolute_error: 2.7422 - val_loss: 20.7736 - val_mean_absolute_error: 2.8296
# Epoch 19/100
# 21/21 [==============================] - 0s 6ms/step - loss: 14.1108 - mean_absolute_error: 2.7288 - val_loss: 19.4817 - val_mean_absolute_error: 2.8285
# Epoch 20/100
# 21/21 [==============================] - 0s 5ms/step - loss: 12.9761 - mean_absolute_error: 2.6208 - val_loss: 20.1093 - val_mean_absolute_error: 2.8280
# Epoch 21/100
# 21/21 [==============================] - 0s 5ms/step - loss: 12.6527 - mean_absolute_error: 2.5506 - val_loss: 19.2644 - val_mean_absolute_error: 2.7992
# Epoch 22/100
# 21/21 [==============================] - 0s 5ms/step - loss: 12.0891 - mean_absolute_error: 2.4963 - val_loss: 19.1362 - val_mean_absolute_error: 2.7714
# Epoch 23/100
# 21/21 [==============================] - 0s 5ms/step - loss: 11.7988 - mean_absolute_error: 2.4597 - val_loss: 18.6277 - val_mean_absolute_error: 2.7639
# Epoch 24/100
# 21/21 [==============================] - 0s 5ms/step - loss: 11.4357 - mean_absolute_error: 2.4286 - val_loss: 18.5976 - val_mean_absolute_error: 2.7546
# Epoch 25/100
# 21/21 [==============================] - 0s 6ms/step - loss: 11.0997 - mean_absolute_error: 2.3744 - val_loss: 18.3169 - val_mean_absolute_error: 2.7266
# Epoch 26/100
# 21/21 [==============================] - 0s 5ms/step - loss: 10.7640 - mean_absolute_error: 2.3543 - val_loss: 17.8413 - val_mean_absolute_error: 2.6889
# Epoch 27/100
# 21/21 [==============================] - 0s 5ms/step - loss: 10.4551 - mean_absolute_error: 2.3084 - val_loss: 17.4542 - val_mean_absolute_error: 2.6598
# Epoch 28/100
# 21/21 [==============================] - 0s 6ms/step - loss: 10.4399 - mean_absolute_error: 2.3241 - val_loss: 17.0286 - val_mean_absolute_error: 2.6304
# Epoch 29/100
# 21/21 [==============================] - 0s 4ms/step - loss: 10.0086 - mean_absolute_error: 2.2580 - val_loss: 17.3826 - val_mean_absolute_error: 2.6493
# Epoch 30/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.8596 - mean_absolute_error: 2.2371 - val_loss: 16.7591 - val_mean_absolute_error: 2.5946
# Epoch 31/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.7415 - mean_absolute_error: 2.2202 - val_loss: 16.9781 - val_mean_absolute_error: 2.6227
# Epoch 32/100
# 21/21 [==============================] - 0s 4ms/step - loss: 9.6849 - mean_absolute_error: 2.2447 - val_loss: 16.4931 - val_mean_absolute_error: 2.6029
# Epoch 33/100
# 21/21 [==============================] - 0s 4ms/step - loss: 9.4705 - mean_absolute_error: 2.1976 - val_loss: 16.3743 - val_mean_absolute_error: 2.5967
# Epoch 34/100
# 21/21 [==============================] - 0s 4ms/step - loss: 9.2259 - mean_absolute_error: 2.1697 - val_loss: 16.4742 - val_mean_absolute_error: 2.5971
# Epoch 35/100
# 21/21 [==============================] - 0s 5ms/step - loss: 9.0224 - mean_absolute_error: 2.1581 - val_loss: 15.7281 - val_mean_absolute_error: 2.5521
# Epoch 36/100
# 21/21 [==============================] - 0s 5ms/step - loss: 8.9430 - mean_absolute_error: 2.1563 - val_loss: 15.7828 - val_mean_absolute_error: 2.5542
# Epoch 37/100
# 21/21 [==============================] - 0s 5ms/step - loss: 8.8654 - mean_absolute_error: 2.1352 - val_loss: 16.2589 - val_mean_absolute_error: 2.6115
# Epoch 38/100
# 21/21 [==============================] - 0s 5ms/step - loss: 8.7119 - mean_absolute_error: 2.1168 - val_loss: 15.9752 - val_mean_absolute_error: 2.5834
# Epoch 39/100
# 21/21 [==============================] - 0s 5ms/step - loss: 8.5466 - mean_absolute_error: 2.1114 - val_loss: 15.6825 - val_mean_absolute_error: 2.5482
# Epoch 40/100
# 21/21 [==============================] - 0s 5ms/step - loss: 8.4744 - mean_absolute_error: 2.0955 - val_loss: 15.6424 - val_mean_absolute_error: 2.5378
# Epoch 41/100
# 21/21 [==============================] - 0s 5ms/step - loss: 8.4215 - mean_absolute_error: 2.0788 - val_loss: 15.6795 - val_mean_absolute_error: 2.5207
# Epoch 42/100
# 21/21 [==============================] - 0s 4ms/step - loss: 8.2377 - mean_absolute_error: 2.0701 - val_loss: 15.3791 - val_mean_absolute_error: 2.5349
# Epoch 43/100
# 21/21 [==============================] - 0s 4ms/step - loss: 8.2315 - mean_absolute_error: 2.0843 - val_loss: 15.5296 - val_mean_absolute_error: 2.5324
# Epoch 44/100
# 21/21 [==============================] - 0s 4ms/step - loss: 8.3170 - mean_absolute_error: 2.0808 - val_loss: 15.3302 - val_mean_absolute_error: 2.5524
# Epoch 45/100
# 21/21 [==============================] - 0s 5ms/step - loss: 8.2040 - mean_absolute_error: 2.0915 - val_loss: 15.3173 - val_mean_absolute_error: 2.5268
# Epoch 46/100
# 21/21 [==============================] - 0s 5ms/step - loss: 7.9620 - mean_absolute_error: 2.0329 - val_loss: 15.1910 - val_mean_absolute_error: 2.5205
# Epoch 47/100
# 21/21 [==============================] - 0s 4ms/step - loss: 8.0324 - mean_absolute_error: 2.0502 - val_loss: 15.2672 - val_mean_absolute_error: 2.5324
# Epoch 48/100
# 21/21 [==============================] - 0s 5ms/step - loss: 8.1524 - mean_absolute_error: 2.0410 - val_loss: 15.3213 - val_mean_absolute_error: 2.5353
# Epoch 49/100
# 21/21 [==============================] - 0s 5ms/step - loss: 7.9188 - mean_absolute_error: 2.0452 - val_loss: 14.9015 - val_mean_absolute_error: 2.5334
# Epoch 50/100
# 21/21 [==============================] - 0s 6ms/step - loss: 7.6965 - mean_absolute_error: 2.0074 - val_loss: 14.9532 - val_mean_absolute_error: 2.5178
# Epoch 51/100
# 21/21 [==============================] - 0s 5ms/step - loss: 7.6163 - mean_absolute_error: 2.0063 - val_loss: 14.8324 - val_mean_absolute_error: 2.5032
# Epoch 52/100
# 21/21 [==============================] - 0s 4ms/step - loss: 7.6481 - mean_absolute_error: 2.0121 - val_loss: 14.9335 - val_mean_absolute_error: 2.5201
# Epoch 53/100
# 21/21 [==============================] - 0s 5ms/step - loss: 7.4590 - mean_absolute_error: 1.9858 - val_loss: 14.7059 - val_mean_absolute_error: 2.4939
# Epoch 54/100
# 21/21 [==============================] - 0s 5ms/step - loss: 7.4737 - mean_absolute_error: 1.9856 - val_loss: 14.5770 - val_mean_absolute_error: 2.4738
# Epoch 55/100
# 21/21 [==============================] - 0s 5ms/step - loss: 7.4812 - mean_absolute_error: 1.9730 - val_loss: 14.8506 - val_mean_absolute_error: 2.4967
# Epoch 56/100
# 21/21 [==============================] - 0s 4ms/step - loss: 7.5274 - mean_absolute_error: 2.0029 - val_loss: 14.9281 - val_mean_absolute_error: 2.4949
# Epoch 57/100
# 21/21 [==============================] - 0s 5ms/step - loss: 7.3129 - mean_absolute_error: 1.9458 - val_loss: 14.6263 - val_mean_absolute_error: 2.4862
# Epoch 58/100
# 21/21 [==============================] - 0s 4ms/step - loss: 7.1284 - mean_absolute_error: 1.9358 - val_loss: 14.8079 - val_mean_absolute_error: 2.4973
# Epoch 59/100
# 21/21 [==============================] - 0s 4ms/step - loss: 7.1600 - mean_absolute_error: 1.9457 - val_loss: 14.7840 - val_mean_absolute_error: 2.5000
# Epoch 60/100
# 21/21 [==============================] - 0s 5ms/step - loss: 7.1012 - mean_absolute_error: 1.9217 - val_loss: 14.4393 - val_mean_absolute_error: 2.4766
# Epoch 61/100
# 21/21 [==============================] - 0s 4ms/step - loss: 7.0234 - mean_absolute_error: 1.9267 - val_loss: 14.8361 - val_mean_absolute_error: 2.4882
# Epoch 62/100
# 21/21 [==============================] - 0s 6ms/step - loss: 7.1138 - mean_absolute_error: 1.9471 - val_loss: 14.4034 - val_mean_absolute_error: 2.4719
# Epoch 63/100
# 21/21 [==============================] - 0s 5ms/step - loss: 7.4474 - mean_absolute_error: 1.9240 - val_loss: 14.6470 - val_mean_absolute_error: 2.4834
# Epoch 64/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.8891 - mean_absolute_error: 1.8925 - val_loss: 14.4343 - val_mean_absolute_error: 2.4814
# Epoch 65/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.9599 - mean_absolute_error: 1.8874 - val_loss: 14.4666 - val_mean_absolute_error: 2.4939
# Epoch 66/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.8554 - mean_absolute_error: 1.9091 - val_loss: 14.3475 - val_mean_absolute_error: 2.4886
# Epoch 67/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.7044 - mean_absolute_error: 1.8613 - val_loss: 14.3957 - val_mean_absolute_error: 2.4824
# Epoch 68/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.6806 - mean_absolute_error: 1.8677 - val_loss: 14.2757 - val_mean_absolute_error: 2.4844
# Epoch 69/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.6651 - mean_absolute_error: 1.8691 - val_loss: 14.2026 - val_mean_absolute_error: 2.4803
# Epoch 70/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.5567 - mean_absolute_error: 1.8308 - val_loss: 14.4231 - val_mean_absolute_error: 2.4588
# Epoch 71/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.5225 - mean_absolute_error: 1.8498 - val_loss: 14.2966 - val_mean_absolute_error: 2.4684
# Epoch 72/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.7630 - mean_absolute_error: 1.8697 - val_loss: 14.1806 - val_mean_absolute_error: 2.4419
# Epoch 73/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.5766 - mean_absolute_error: 1.8568 - val_loss: 14.0890 - val_mean_absolute_error: 2.4557
# Epoch 74/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.6400 - mean_absolute_error: 1.8792 - val_loss: 14.6181 - val_mean_absolute_error: 2.5132
# Epoch 75/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.5147 - mean_absolute_error: 1.8421 - val_loss: 13.9229 - val_mean_absolute_error: 2.4296
# Epoch 76/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.2919 - mean_absolute_error: 1.8059 - val_loss: 14.2341 - val_mean_absolute_error: 2.4817
# Epoch 77/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.4623 - mean_absolute_error: 1.8091 - val_loss: 13.8568 - val_mean_absolute_error: 2.4360
# Epoch 78/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.3900 - mean_absolute_error: 1.8387 - val_loss: 14.0783 - val_mean_absolute_error: 2.4546
# Epoch 79/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.1596 - mean_absolute_error: 1.7932 - val_loss: 13.9843 - val_mean_absolute_error: 2.4206
# Epoch 80/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.1661 - mean_absolute_error: 1.7871 - val_loss: 13.6722 - val_mean_absolute_error: 2.4204
# Epoch 81/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.1100 - mean_absolute_error: 1.7906 - val_loss: 13.8792 - val_mean_absolute_error: 2.4268
# Epoch 82/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.0254 - mean_absolute_error: 1.7596 - val_loss: 14.0002 - val_mean_absolute_error: 2.4456
# Epoch 83/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.0924 - mean_absolute_error: 1.7998 - val_loss: 13.9823 - val_mean_absolute_error: 2.4447
# Epoch 84/100
# 21/21 [==============================] - 0s 5ms/step - loss: 5.9715 - mean_absolute_error: 1.7613 - val_loss: 13.7461 - val_mean_absolute_error: 2.4214
# Epoch 85/100
# 21/21 [==============================] - 0s 5ms/step - loss: 6.1301 - mean_absolute_error: 1.7804 - val_loss: 13.7998 - val_mean_absolute_error: 2.4239
# Epoch 86/100
# 21/21 [==============================] - 0s 4ms/step - loss: 5.9325 - mean_absolute_error: 1.7564 - val_loss: 13.9144 - val_mean_absolute_error: 2.4338
# Epoch 87/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.1666 - mean_absolute_error: 1.8127 - val_loss: 14.0688 - val_mean_absolute_error: 2.4723
# Epoch 88/100
# 21/21 [==============================] - 0s 5ms/step - loss: 5.8817 - mean_absolute_error: 1.7242 - val_loss: 14.3636 - val_mean_absolute_error: 2.5335
# Epoch 89/100
# 21/21 [==============================] - 0s 4ms/step - loss: 6.0470 - mean_absolute_error: 1.8139 - val_loss: 13.8864 - val_mean_absolute_error: 2.4669
# Epoch 90/100
# 21/21 [==============================] - 0s 6ms/step - loss: 5.7248 - mean_absolute_error: 1.7247 - val_loss: 13.5428 - val_mean_absolute_error: 2.3988
# Epoch 91/100
# 21/21 [==============================] - 0s 5ms/step - loss: 5.7050 - mean_absolute_error: 1.7330 - val_loss: 13.8636 - val_mean_absolute_error: 2.4092
# Epoch 92/100
# 21/21 [==============================] - 0s 6ms/step - loss: 5.6701 - mean_absolute_error: 1.6990 - val_loss: 13.6613 - val_mean_absolute_error: 2.3974
# Epoch 93/100
# 21/21 [==============================] - 0s 4ms/step - loss: 5.6312 - mean_absolute_error: 1.7111 - val_loss: 13.5700 - val_mean_absolute_error: 2.4135
# Epoch 94/100
# 21/21 [==============================] - 0s 5ms/step - loss: 5.5520 - mean_absolute_error: 1.6786 - val_loss: 13.5211 - val_mean_absolute_error: 2.4208
# Epoch 95/100
# 21/21 [==============================] - 0s 6ms/step - loss: 5.6334 - mean_absolute_error: 1.7081 - val_loss: 13.4894 - val_mean_absolute_error: 2.3840
# Epoch 96/100
# 21/21 [==============================] - 0s 5ms/step - loss: 5.5294 - mean_absolute_error: 1.6960 - val_loss: 13.3788 - val_mean_absolute_error: 2.4100
# Epoch 97/100
# 21/21 [==============================] - 0s 4ms/step - loss: 5.6946 - mean_absolute_error: 1.7150 - val_loss: 14.0034 - val_mean_absolute_error: 2.4711
# Epoch 98/100
# 21/21 [==============================] - 0s 5ms/step - loss: 5.4481 - mean_absolute_error: 1.6761 - val_loss: 13.3676 - val_mean_absolute_error: 2.3972
# Epoch 99/100
# 21/21 [==============================] - 0s 4ms/step - loss: 5.4173 - mean_absolute_error: 1.6748 - val_loss: 13.4129 - val_mean_absolute_error: 2.4204
# Epoch 100/100
# 21/21 [==============================] - 0s 4ms/step - loss: 5.4461 - mean_absolute_error: 1.6588 - val_loss: 13.6210 - val_mean_absolute_error: 2.4324

# %%
model_4 = keras.Sequential(name='model-4')
model_4.add(layers.Dense(64, activation='relu', input_shape=(13,)))
model_4.add(layers.Dropout(0.2))
model_4.add(layers.Dense(64, activation='relu'))
model_4.add(layers.Dropout(0.2))
model_4.add(layers.Dense(1))

model_4.compile(keras.optimizers.Adam(0.001),
                loss=keras.losses.MeanSquaredError(),
                metrics=[keras.metrics.MeanAbsoluteError()])

log_dir = os.path.join('lab2-logs', 'model-4')
model_cbk = keras.callbacks.TensorBoard(log_dir=log_dir)
model_mckp = keras.callbacks.ModelCheckpoint(model_dir + '/Best-model-4.keras',
                                             monitor='val_mean_absolute_error',
                                             save_best_only=True,
                                             mode='min')
es = keras.callbacks.EarlyStopping(monitor='val_mean_absolute_error', mode='min', patience=10)
model_4.fit(train_data, train_targets,  # 傳入訓練數據
               batch_size=16,  # 批次大小設為16
               epochs=100,  # 整個dataset訓練100遍
               validation_data=(val_data, val_targets),  # 驗證數據
               callbacks=[model_cbk, model_mckp, es])
# Out:
# Epoch 1/100
# 21/21 [==============================] - 1s 12ms/step - loss: 554.2830 - mean_absolute_error: 21.6523 - val_loss: 539.7896 - val_mean_absolute_error: 21.5399
# Epoch 2/100
# 21/21 [==============================] - 0s 6ms/step - loss: 479.0319 - mean_absolute_error: 19.8582 - val_loss: 438.8899 - val_mean_absolute_error: 19.1516
# Epoch 3/100
# 21/21 [==============================] - 0s 5ms/step - loss: 354.6234 - mean_absolute_error: 16.5465 - val_loss: 276.2072 - val_mean_absolute_error: 14.6170
# Epoch 4/100
# 21/21 [==============================] - 0s 6ms/step - loss: 197.8244 - mean_absolute_error: 11.4146 - val_loss: 124.7184 - val_mean_absolute_error: 8.5987
# Epoch 5/100
# 21/21 [==============================] - 0s 5ms/step - loss: 97.8586 - mean_absolute_error: 7.3913 - val_loss: 73.7941 - val_mean_absolute_error: 6.2953
# Epoch 6/100
# 21/21 [==============================] - 0s 5ms/step - loss: 65.6025 - mean_absolute_error: 6.1391 - val_loss: 53.3755 - val_mean_absolute_error: 5.0979
# Epoch 7/100
# 21/21 [==============================] - 0s 6ms/step - loss: 54.7172 - mean_absolute_error: 5.4731 - val_loss: 40.5792 - val_mean_absolute_error: 4.2006
# Epoch 8/100
# 21/21 [==============================] - 0s 6ms/step - loss: 45.7494 - mean_absolute_error: 4.9541 - val_loss: 33.9881 - val_mean_absolute_error: 3.6908
# Epoch 9/100
# 21/21 [==============================] - 0s 6ms/step - loss: 35.1385 - mean_absolute_error: 4.4903 - val_loss: 30.5998 - val_mean_absolute_error: 3.4326
# Epoch 10/100
# 21/21 [==============================] - 0s 5ms/step - loss: 31.0003 - mean_absolute_error: 4.1038 - val_loss: 27.2570 - val_mean_absolute_error: 3.2772
# Epoch 11/100
# 21/21 [==============================] - 0s 5ms/step - loss: 28.7662 - mean_absolute_error: 3.9675 - val_loss: 25.8444 - val_mean_absolute_error: 3.1450
# Epoch 12/100
# 21/21 [==============================] - 0s 5ms/step - loss: 31.8406 - mean_absolute_error: 4.2292 - val_loss: 24.7358 - val_mean_absolute_error: 2.9936
# Epoch 13/100
# 21/21 [==============================] - 0s 5ms/step - loss: 26.5470 - mean_absolute_error: 3.7237 - val_loss: 24.8436 - val_mean_absolute_error: 2.9970
# Epoch 14/100
# 21/21 [==============================] - 0s 6ms/step - loss: 26.4541 - mean_absolute_error: 3.8482 - val_loss: 22.9256 - val_mean_absolute_error: 2.8770
# Epoch 15/100
# 21/21 [==============================] - 0s 6ms/step - loss: 28.2254 - mean_absolute_error: 3.8912 - val_loss: 21.7010 - val_mean_absolute_error: 2.8323
# Epoch 16/100
# 21/21 [==============================] - 0s 5ms/step - loss: 27.6973 - mean_absolute_error: 3.9011 - val_loss: 21.2832 - val_mean_absolute_error: 2.7594
# Epoch 17/100
# 21/21 [==============================] - 0s 5ms/step - loss: 23.4225 - mean_absolute_error: 3.6544 - val_loss: 20.6388 - val_mean_absolute_error: 2.7476
# Epoch 18/100
# 21/21 [==============================] - 0s 5ms/step - loss: 24.9311 - mean_absolute_error: 3.7220 - val_loss: 20.5012 - val_mean_absolute_error: 2.6864
# Epoch 19/100
# 21/21 [==============================] - 0s 5ms/step - loss: 23.3654 - mean_absolute_error: 3.5951 - val_loss: 18.9124 - val_mean_absolute_error: 2.6609
# Epoch 20/100
# 21/21 [==============================] - 0s 5ms/step - loss: 21.3602 - mean_absolute_error: 3.5015 - val_loss: 19.1158 - val_mean_absolute_error: 2.6395
# Epoch 21/100
# 21/21 [==============================] - 0s 4ms/step - loss: 23.2681 - mean_absolute_error: 3.4742 - val_loss: 18.9459 - val_mean_absolute_error: 2.6479
# Epoch 22/100
# 21/21 [==============================] - 0s 6ms/step - loss: 18.3537 - mean_absolute_error: 3.3802 - val_loss: 19.3449 - val_mean_absolute_error: 2.6335
# Epoch 23/100
# 21/21 [==============================] - 0s 6ms/step - loss: 22.1544 - mean_absolute_error: 3.4510 - val_loss: 18.7312 - val_mean_absolute_error: 2.6209
# Epoch 24/100
# 21/21 [==============================] - 0s 6ms/step - loss: 24.8915 - mean_absolute_error: 3.7027 - val_loss: 17.5520 - val_mean_absolute_error: 2.5219
# Epoch 25/100
# 21/21 [==============================] - 0s 4ms/step - loss: 19.6655 - mean_absolute_error: 3.2994 - val_loss: 18.2598 - val_mean_absolute_error: 2.5875
# Epoch 26/100
# 21/21 [==============================] - 0s 4ms/step - loss: 19.4390 - mean_absolute_error: 3.4147 - val_loss: 17.2408 - val_mean_absolute_error: 2.5350
# Epoch 27/100
# 21/21 [==============================] - 0s 5ms/step - loss: 22.1575 - mean_absolute_error: 3.6299 - val_loss: 17.1297 - val_mean_absolute_error: 2.4476
# Epoch 28/100
# 21/21 [==============================] - 0s 4ms/step - loss: 18.9061 - mean_absolute_error: 3.2801 - val_loss: 18.3870 - val_mean_absolute_error: 2.5941
# Epoch 29/100
# 21/21 [==============================] - 0s 6ms/step - loss: 18.4935 - mean_absolute_error: 3.2640 - val_loss: 16.4448 - val_mean_absolute_error: 2.4244
# Epoch 30/100
# 21/21 [==============================] - 0s 5ms/step - loss: 20.5381 - mean_absolute_error: 3.2862 - val_loss: 16.4136 - val_mean_absolute_error: 2.4267
# Epoch 31/100
# 21/21 [==============================] - 0s 4ms/step - loss: 20.9351 - mean_absolute_error: 3.4294 - val_loss: 16.7592 - val_mean_absolute_error: 2.4506
# Epoch 32/100
# 21/21 [==============================] - 0s 5ms/step - loss: 20.7240 - mean_absolute_error: 3.3442 - val_loss: 17.2126 - val_mean_absolute_error: 2.4810
# Epoch 33/100
# 21/21 [==============================] - 0s 6ms/step - loss: 19.9332 - mean_absolute_error: 3.4077 - val_loss: 16.5242 - val_mean_absolute_error: 2.4191
# Epoch 34/100
# 21/21 [==============================] - 0s 15ms/step - loss: 20.6650 - mean_absolute_error: 3.4188 - val_loss: 16.3887 - val_mean_absolute_error: 2.4781
# Epoch 35/100
# 21/21 [==============================] - 0s 7ms/step - loss: 19.4854 - mean_absolute_error: 3.2807 - val_loss: 15.9746 - val_mean_absolute_error: 2.3972
# Epoch 36/100
# 21/21 [==============================] - 0s 5ms/step - loss: 19.6932 - mean_absolute_error: 3.2459 - val_loss: 16.6790 - val_mean_absolute_error: 2.5041
# Epoch 37/100
# 21/21 [==============================] - 0s 5ms/step - loss: 20.8015 - mean_absolute_error: 3.3469 - val_loss: 15.8682 - val_mean_absolute_error: 2.3949
# Epoch 38/100
# 21/21 [==============================] - 0s 4ms/step - loss: 19.1289 - mean_absolute_error: 3.3146 - val_loss: 16.2738 - val_mean_absolute_error: 2.4958
# Epoch 39/100
# 21/21 [==============================] - 0s 10ms/step - loss: 17.7448 - mean_absolute_error: 3.1747 - val_loss: 15.1589 - val_mean_absolute_error: 2.3721
# Epoch 40/100
# 21/21 [==============================] - 0s 12ms/step - loss: 18.3750 - mean_absolute_error: 3.1769 - val_loss: 15.5058 - val_mean_absolute_error: 2.3981
# Epoch 41/100
# 21/21 [==============================] - 0s 4ms/step - loss: 17.1359 - mean_absolute_error: 3.0745 - val_loss: 15.7265 - val_mean_absolute_error: 2.4383
# Epoch 42/100
# 21/21 [==============================] - 0s 5ms/step - loss: 20.1178 - mean_absolute_error: 3.3079 - val_loss: 15.9002 - val_mean_absolute_error: 2.3978
# Epoch 43/100
# 21/21 [==============================] - 0s 5ms/step - loss: 20.5156 - mean_absolute_error: 3.4675 - val_loss: 16.1058 - val_mean_absolute_error: 2.6002
# Epoch 44/100
# 21/21 [==============================] - 0s 5ms/step - loss: 19.0516 - mean_absolute_error: 3.2364 - val_loss: 15.2818 - val_mean_absolute_error: 2.3776
# Epoch 45/100
# 21/21 [==============================] - 0s 4ms/step - loss: 16.4677 - mean_absolute_error: 3.0103 - val_loss: 15.6211 - val_mean_absolute_error: 2.4193
# Epoch 46/100
# 21/21 [==============================] - 0s 10ms/step - loss: 19.1651 - mean_absolute_error: 3.3117 - val_loss: 14.9343 - val_mean_absolute_error: 2.4106
# Epoch 47/100
# 21/21 [==============================] - 0s 10ms/step - loss: 17.1490 - mean_absolute_error: 3.1188 - val_loss: 16.0529 - val_mean_absolute_error: 2.4512
# Epoch 48/100
# 21/21 [==============================] - 0s 5ms/step - loss: 21.1069 - mean_absolute_error: 3.3701 - val_loss: 15.1682 - val_mean_absolute_error: 2.3804
# Epoch 49/100
# 21/21 [==============================] - 0s 5ms/step - loss: 17.7888 - mean_absolute_error: 3.1250 - val_loss: 15.2290 - val_mean_absolute_error: 2.3689
# Epoch 50/100
# 21/21 [==============================] - 0s 5ms/step - loss: 18.2315 - mean_absolute_error: 3.3675 - val_loss: 15.8402 - val_mean_absolute_error: 2.4232
# Epoch 51/100
# 21/21 [==============================] - 0s 5ms/step - loss: 17.0431 - mean_absolute_error: 3.1167 - val_loss: 15.3597 - val_mean_absolute_error: 2.4078
# Epoch 52/100
# 21/21 [==============================] - 0s 5ms/step - loss: 19.0676 - mean_absolute_error: 3.2114 - val_loss: 15.5697 - val_mean_absolute_error: 2.4883
# Epoch 53/100
# 21/21 [==============================] - 0s 5ms/step - loss: 16.4809 - mean_absolute_error: 3.1282 - val_loss: 14.2066 - val_mean_absolute_error: 2.3922
# Epoch 54/100
# 21/21 [==============================] - 0s 5ms/step - loss: 15.9767 - mean_absolute_error: 3.1107 - val_loss: 15.0744 - val_mean_absolute_error: 2.4079
# Epoch 55/100
# 21/21 [==============================] - 0s 4ms/step - loss: 16.4649 - mean_absolute_error: 3.0132 - val_loss: 14.5678 - val_mean_absolute_error: 2.3896
# Epoch 56/100
# 21/21 [==============================] - 0s 6ms/step - loss: 15.4098 - mean_absolute_error: 2.9612 - val_loss: 14.7289 - val_mean_absolute_error: 2.3591
# Epoch 57/100
# 21/21 [==============================] - 0s 5ms/step - loss: 18.2981 - mean_absolute_error: 3.2635 - val_loss: 14.9347 - val_mean_absolute_error: 2.4690
# Epoch 58/100
# 21/21 [==============================] - 0s 6ms/step - loss: 15.5568 - mean_absolute_error: 3.0280 - val_loss: 14.3669 - val_mean_absolute_error: 2.3208
# Epoch 59/100
# 21/21 [==============================] - 0s 6ms/step - loss: 17.6050 - mean_absolute_error: 3.2247 - val_loss: 14.6388 - val_mean_absolute_error: 2.3042
# Epoch 60/100
# 21/21 [==============================] - 0s 5ms/step - loss: 15.8656 - mean_absolute_error: 3.0594 - val_loss: 14.3541 - val_mean_absolute_error: 2.3788
# Epoch 61/100
# 21/21 [==============================] - 0s 5ms/step - loss: 16.6892 - mean_absolute_error: 3.1031 - val_loss: 14.1906 - val_mean_absolute_error: 2.3552
# Epoch 62/100
# 21/21 [==============================] - 0s 5ms/step - loss: 18.6722 - mean_absolute_error: 3.2953 - val_loss: 14.1251 - val_mean_absolute_error: 2.3323
# Epoch 63/100
# 21/21 [==============================] - 0s 4ms/step - loss: 19.0608 - mean_absolute_error: 3.1756 - val_loss: 14.6251 - val_mean_absolute_error: 2.3887
# Epoch 64/100
# 21/21 [==============================] - 0s 4ms/step - loss: 18.0781 - mean_absolute_error: 3.1821 - val_loss: 14.4947 - val_mean_absolute_error: 2.3752
# Epoch 65/100
# 21/21 [==============================] - 0s 5ms/step - loss: 19.8508 - mean_absolute_error: 3.3202 - val_loss: 15.1975 - val_mean_absolute_error: 2.4327
# Epoch 66/100
# 21/21 [==============================] - 0s 4ms/step - loss: 19.8035 - mean_absolute_error: 3.3849 - val_loss: 14.3658 - val_mean_absolute_error: 2.3356
# Epoch 67/100
# 21/21 [==============================] - 0s 5ms/step - loss: 17.5538 - mean_absolute_error: 3.2489 - val_loss: 15.3331 - val_mean_absolute_error: 2.4486
# Epoch 68/100
# 21/21 [==============================] - 0s 4ms/step - loss: 16.3193 - mean_absolute_error: 3.0972 - val_loss: 14.2733 - val_mean_absolute_error: 2.3759
# Epoch 69/100
# 21/21 [==============================] - 0s 4ms/step - loss: 16.6640 - mean_absolute_error: 3.0199 - val_loss: 14.4843 - val_mean_absolute_error: 2.3855

# %%
model = keras.models.load_model('lab1-logs/models/Best-model-2.keras')

# 預測測試數據
y_pred = model.predict(test_data)
print(y_pred.shape)
print(test_targets.shape)

# 不需要將預測結果轉換回來(因為訓練時的訓練目標並沒有經過標準化)
# y_pred = np.reshape(y_pred * std['price'] + mean['price'], y_test.shape)

y_pred = np.reshape(y_pred, test_targets.shape)
print(y_pred.shape, test_targets.shape)
# 計算平均的誤差百分比
percentage_error = np.mean(np.abs(test_targets - y_pred) / test_targets) * 100
# 顯示誤差百分比
print("Model_1 Percentage Error: {:.2f}%".format(percentage_error))
# Out:
# 4/4 [==============================] - 0s 3ms/step
# (102, 1)
# (102,)
# (102,) (102,)
# Model_1 Percentage Error: 17.10%

# %%
model = keras.models.load_model('lab1-logs/models/Best-model-3.keras')

# 預測測試數據
y_pred = model.predict(test_data)
print(y_pred.shape)
print(test_targets.shape)

# 不需要將預測結果轉換回來(因為訓練時的訓練目標並沒有經過標準化)
# y_pred = np.reshape(y_pred * std['price'] + mean['price'], y_test.shape)

y_pred = np.reshape(y_pred, test_targets.shape)
print(y_pred.shape, test_targets.shape)
# 計算平均的誤差百分比
percentage_error = np.mean(np.abs(test_targets - y_pred) / test_targets) * 100
# 顯示誤差百分比
print("Model_1 Percentage Error: {:.2f}%".format(percentage_error))
# Out:
# 4/4 [==============================] - 0s 2ms/step
# (102, 1)
# (102,)
# (102,) (102,)
# Model_1 Percentage Error: 14.71%

# %%
model = keras.models.load_model('lab1-logs/models/Best-model-4.keras')

# 預測測試數據
y_pred = model.predict(test_data)
print(y_pred.shape)
print(test_targets.shape)

# 不需要將預測結果轉換回來(因為訓練時的訓練目標並沒有經過標準化)
# y_pred = np.reshape(y_pred * std['price'] + mean['price'], y_test.shape)

y_pred = np.reshape(y_pred, test_targets.shape)
print(y_pred.shape, test_targets.shape)
# 計算平均的誤差百分比
percentage_error = np.mean(np.abs(test_targets - y_pred) / test_targets) * 100
# 顯示誤差百分比
print("Model_1 Percentage Error: {:.2f}%".format(percentage_error))
# Out:
# 4/4 [==============================] - 0s 3ms/step
# (102, 1)
# (102,)
# (102,) (102,)
# Model_1 Percentage Error: 15.62%
