# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import initializers

# %% [markdown]
# 權重初始化(請改變activation functione 觀察各層輸出結果)

# %% [markdown]
# 1.RandomNormal (std 1 )  relu

# %% [markdown]
# 2.RandomNormal (std 0.01 ) relu

# %% [markdown]
# 4.Xavier/Glorot Initialization (tanh)

# %% [markdown]
# 5.He initialization (tanh)

# %% [markdown]
# ##使用mnist數據集實驗證三種權重初始化方法 及 BN

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import utils
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load Dataset
# - MNIST dataset
# - source: http://yann.lecun.com/exdb/mnist/

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
plt.imshow(X_train[0], cmap="gray")    # show first number in the dataset
plt.show()
print('Label: ', y_train[0])
# Out:
# Label:  5

# %%
plt.imshow(X_test[0], cmap="gray")    # show first number in the dataset
plt.show()
print('Label: ', y_test[0])
# Out:
# Label:  7

# %%
# converting y data into categorical (one-hot encoding)
